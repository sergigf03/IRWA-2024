# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
from numpy import linalg as la
import time

# %%
# if you do not have 'nltk', the following command should work "python -m pip install nltk"
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
tweets_path = '/content/drive/MyDrive/RIAW/data/farmers-protest-tweets.json'
tweet_doc_ids_map_path = '/content/drive/MyDrive/RIAW/data/tweet_document_ids_map.csv'
evaluation_path = '/content/drive/MyDrive/RIAW/data/evaluation.csv'

# %%
import json
import re
import string
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer


# Load the JSON dataset line by line
tweets_data = []
with open(tweets_path, 'r', encoding='utf-8') as f:
    for line in f:
        # Each line is a separate JSON object
        tweets_data.append(json.loads(line))


# Load the tweet-to-document ID map
tweet_doc_ids_map = pd.read_csv(tweet_doc_ids_map_path)

# Convert the mapping into a dictionary for fast lookups (tweet_id -> document_id)
tweet_to_doc_map = dict(zip(tweet_doc_ids_map['id'], tweet_doc_ids_map['docId']))

# Function to preprocess tweet content
def build_terms(line):
    """
    Preprocess the tweet content by removing stop words, punctuation, and applying stemming.

    Argument:
    line -- string (text to preprocess)

    Returns:
    A list of tokens corresponding to the preprocessed text.
    """
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))

    # Convert to lowercase
    line = line.lower()

    # Remove punctuation (except for #)
    line = line.translate(str.maketrans('', '', string.punctuation.replace('#', '')))

    # Tokenize the text
    line = line.split()

    # Remove stopwords
    line = [word for word in line if word not in stop_words]

    # Apply stemming
    line = [stemmer.stem(word) for word in line]

    return line

# Function to extract hashtags from the tweet
def extract_hashtags(text):
    """
    Extracts hashtags from the tweet content.

    Argument:
    text -- string (tweet content)

    Returns:
    hashtags - a list of hashtags found in the tweet
    """
    hashtags = re.findall(r'#\w+', text)  # Find hashtags using regular expressions
    return hashtags

# Function to process a tweet and return the required structure
def process_tweet(tweet):
    """
    Processes a single tweet and returns the required information structure, including document ID.

    Argument:
    tweet -- dictionary containing tweet data

    Returns:
    processed_tweet -- dictionary with the tweet's preprocessed content and metadata
    """
    tweet_id = tweet['id']  # Get the tweet ID

    # Fetch the document ID mapped to this tweet ID
    document_id = tweet_to_doc_map.get(tweet_id, None)

    tweet_content = tweet['content']  # Get the tweet content

    # Preprocess the tweet content
    preprocessed_content = build_terms(tweet_content)

    # Extract hashtags
    hashtags = extract_hashtags(tweet_content)

    # Structure the final output
    processed_tweet = {
        'Tweet': ' '.join(preprocessed_content),  # Preprocessed tweet content
        'Date': tweet['date'],
        'Hashtags': hashtags,
        'Likes': tweet['likeCount'],
        'Retweets': tweet['retweetCount'],
        'Url': tweet['url']
    }

    return document_id, processed_tweet

# Dictionary to store the results
doc_tweet_map = {}

# Process all tweets and store them in a dictionary of dictionaries
for tweet in tweets_data:
    document_id, processed_tweet = process_tweet(tweet)

    if document_id:  # Ensure the tweet has a valid document ID
        # Store the processed tweet under the document ID
        doc_tweet_map[document_id] = processed_tweet

# Example: Print the dictionary for the first few document IDs
for doc_id, tweet_info in list(doc_tweet_map.items())[:5]:
    print(f"Doc ID: {doc_id}\nTweet Info: {tweet_info}\n")
# Out:
# Doc ID: doc_0
# Tweet Info: {'Tweet': 'world progress indian polic govt still tri take india back horrif past tyranni narendramodi delhipolic shame #modidontsellfarm #farmersprotest #freenodeepkaur httpstcoes3kn0iqaf', 'Date': '2021-02-24T09:23:35+00:00', 'Hashtags': ['#ModiDontSellFarmers', '#FarmersProtest', '#FreeNodeepKaur'], 'Likes': 0, 'Retweets': 0, 'Url': 'https://twitter.com/ArjunSinghPanam/status/1364506249291784198'}
#
# Doc ID: doc_1
# Tweet Info: {'Tweet': '#farmersprotest #modiignoringfarmersdeath #modidontsellfarm kisanektamorcha farmer constantli distroy crop throughout india realli heart breakingw care crop like children govt agricultur minist laugh us🚜🌾w win💪 httpstcoklspngg9x', 'Date': '2021-02-24T09:23:32+00:00', 'Hashtags': ['#FarmersProtest', '#ModiIgnoringFarmersDeaths', '#ModiDontSellFarmers'], 'Likes': 0, 'Retweets': 0, 'Url': 'https://twitter.com/PrdeepNain/status/1364506237451313155'}
#
# Doc ID: doc_2
# Tweet Info: {'Tweet': 'reallyswara rohinisgh watch full video httpstcowbpndjdb0n #farmersprotest #nofarmersnofood httpstcofustokocxk', 'Date': '2021-02-24T09:23:16+00:00', 'Hashtags': ['#farmersprotest', '#NoFarmersNoFood'], 'Likes': 0, 'Retweets': 0, 'Url': 'https://twitter.com/anmoldhaliwal/status/1364506167226032128'}
#
# Doc ID: doc_3
# Tweet Info: {'Tweet': 'mandeeppunia1 watch full video httpstcowbpndjdb0n #farmersprotest #nofarmersnofood httpstco71imqec6ak', 'Date': '2021-02-24T09:22:34+00:00', 'Hashtags': ['#farmersprotest', '#NoFarmersNoFood'], 'Likes': 0, 'Retweets': 0, 'Url': 'https://twitter.com/anmoldhaliwal/status/1364505991887347714'}
#
# Doc ID: doc_4
# Tweet Info: {'Tweet': 'mandeeppunia1 watch full video httpstcowbpndjdb0n #farmersprotest #nofarmersnofood httpstconfmjeqrtj2', 'Date': '2021-02-24T09:21:51+00:00', 'Hashtags': ['#farmersprotest', '#NoFarmersNoFood'], 'Likes': 0, 'Retweets': 0, 'Url': 'https://twitter.com/anmoldhaliwal/status/1364505813834989568'}

# %%
def create_inverted_index(tweets_data, tweet_to_doc_map):
    """
    Creates an inverted index for the protest tweets dataset.

    Arguments:
    tweets_data -- list of tweet dictionaries with fields like 'id' and 'content'
    tweet_to_doc_map -- dictionary mapping tweet IDs to document IDs

    Returns:
    inverted_index -- dictionary with terms as keys and posting lists as values.
                      Each posting list contains tuples of (document ID, positions).
    """
    inverted_index = defaultdict(list)

    # Loop through each tweet
    for tweet in tweets_data:
        tweet_id = tweet['id']
        document_id = tweet_to_doc_map.get(tweet_id, None)

        # Skip if the document ID is not found
        if not document_id:
            continue

        # Preprocess the tweet content to get terms
        terms = build_terms(tweet['content'])

        # Create a dictionary to track term positions in the current tweet
        current_tweet_index = defaultdict(lambda: (document_id, array('I')))

        # Loop through the terms and store their positions
        for position, term in enumerate(terms):
            current_tweet_index[term][1].append(position)

        # Merge the current tweet index with the main inverted index
        for term, posting in current_tweet_index.items():
            inverted_index[term].append(posting)

    return inverted_index

# Creating the inverted index
inverted_index = create_inverted_index(tweets_data, tweet_to_doc_map)

# Check a few entries in the inverted index
for term, postings in list(inverted_index.items())[:5]:
    print(f"Term: {term}")
    for doc_id, positions in postings:
        print(f" - Document ID: {doc_id}, Positions: {list(positions)}")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#  - Document ID: doc_20561, Positions: [14]
#  - Document ID: doc_20623, Positions: [1]
#  - Document ID: doc_20674, Positions: [8]
#  - Document ID: doc_20708, Positions: [4]
#  - Document ID: doc_20747, Positions: [0]
#  - Document ID: doc_20778, Positions: [2]
#  - Document ID: doc_20789, Positions: [5]
#  - Document ID: doc_20818, Positions: [0]
#  - Document ID: doc_20832, Positions: [6]
#  - Document ID: doc_20851, Positions: [17]
#  - Document ID: doc_20855, Positions: [3]
#  - Document ID: doc_20864, Positions: [15]
#  - Document ID: doc_20992, Positions: [1]
#  - Document ID: doc_21006, Positions: [15, 19]
#  - Document ID: doc_21022, Positions: [7]
#  - Document ID: doc_21063, Positions: [9]
#  - Document ID: doc_21075, Positions: [3]
#  - Document ID: doc_21101, Positions: [4]
#  - Document ID: doc_21127, Positions: [9]
#  - Document ID: doc_21153, Positions: [9]
#  - Document ID: doc_21165, Positions: [0]
#  - Document ID: doc_21228, Positions: [6]
#  - Document ID: doc_21248, Positions: [1]
#  - Document ID: doc_21355, Positions: [0]
#  - Document ID: doc_21433, Positions: [16]
#  - Document ID: doc_21486, Positions: [0, 4]
#  - Document ID: doc_21600, Positions: [14]
#  - Document ID: doc_21681, Positions: [3]
#  - Document ID: doc_21692, Positions: [1]
#  - Document ID: doc_21848, Positions: [9]
#  - Document ID: doc_21895, Positions: [3]
#  - Document ID: doc_21896, Positions: [0]
#  - Document ID: doc_21900, Positions: [8]
#  - Document ID: doc_21906, Positions: [4]
#  - Document ID: doc_21932, Positions: [12]
#  - Document ID: doc_21938, Positions: [0]
#  - Document ID: doc_21948, Positions: [6]
#  - Document ID: doc_22088, Positions: [9]
#  - Document ID: doc_22112, Positions: [7]
#  - Document ID: doc_22165, Positions: [16]
#  - Document ID: doc_22176, Positions: [20]
#  - Document ID: doc_22197, Positions: [10]
#  - Document ID: doc_22198, Positions: [10]
#  - Document ID: doc_22209, Positions: [11]
#  - Document ID: doc_22214, Positions: [3]
#  - Document ID: doc_22215, Positions: [19]
#  - Document ID: doc_22219, Positions: [4]
#  - Document ID: doc_22232, Positions: [1]
#  - Document ID: doc_22233, Positions: [15]
#  - Document ID: doc_22250, Positions: [9, 16]
#  - Document ID: doc_22281, Positions: [3]
#  - Document ID: doc_22284, Positions: [7]
#  - Document ID: doc_22291, Positions: [3]
#  - Document ID: doc_22314, Positions: [6]
#  - Document ID: doc_22336, Positions: [0]
#  - Document ID: doc_22361, Positions: [2]
#  - Document ID: doc_22367, Positions: [6]
#  - Document ID: doc_22374, Positions: [2, 5]
#  - Document ID: doc_22395, Positions: [2]
#  - Document ID: doc_22398, Positions: [6]
#  - Document ID: doc_22399, Positions: [4]
#  - Document ID: doc_22402, Positions: [6]
#  - Document ID: doc_22403, Positions: [6]
#  - Document ID: doc_22449, Positions: [3]
#  - Document ID: doc_22465, Positions: [9]
#  - Document ID: doc_22483, Positions: [11]
#  - Document ID: doc_22487, Positions: [6]
#  - Document ID: doc_22489, Positions: [4]
#  - Document ID: doc_22519, Positions: [1]
#  - Document ID: doc_22522, Positions: [5]
#  - Document ID: doc_22539, Positions: [9]
#  - Document ID: doc_22560, Positions: [11]
#  - Document ID: doc_22563, Positions: [11]
#  - Document ID: doc_22570, Positions: [0]
#  - Document ID: doc_22579, Positions: [5]
#  - Document ID: doc_22591, Positions: [13]
#  - Document ID: doc_22593, Positions: [3]
#  - Document ID: doc_22595, Positions: [9]
#  - Document ID: doc_22605, Positions: [0]
#  - Document ID: doc_22608, Positions: [8]
#  - Document ID: doc_22629, Positions: [4]
#  - Document ID: doc_22632, Positions: [8]
#  - Document ID: doc_22636, Positions: [1]
#  - Document ID: doc_22650, Positions: [2, 12]
#  - Document ID: doc_22669, Positions: [13, 15]
#  - Document ID: doc_22700, Positions: [11, 20]
#  - Document ID: doc_22702, Positions: [16]
#  - Document ID: doc_22708, Positions: [1]
#  - Document ID: doc_22718, Positions: [7]
#  - Document ID: doc_22724, Positions: [1, 6]
#  - Document ID: doc_22740, Positions: [9]
#  - Document ID: doc_22749, Positions: [2]
#  - Document ID: doc_22766, Positions: [6]
#  - Document ID: doc_22788, Positions: [1]
#  - Document ID: doc_22798, Positions: [6]
#  - Document ID: doc_22809, Positions: [17]
#  - Document ID: doc_22857, Positions: [5]
#  - Document ID: doc_22878, Positions: [10]
#  - Document ID: doc_22886, Positions: [10]
#  - Document ID: doc_22895, Positions: [6]
#  - Document ID: doc_22903, Positions: [23]
#  - Document ID: doc_22913, Positions: [6]
#  - Document ID: doc_22923, Positions: [6]
#  - Document ID: doc_22978, Positions: [1]
#  - Document ID: doc_22982, Positions: [5]
#  - Document ID: doc_23005, Positions: [10]
#  - Document ID: doc_23015, Positions: [9]
#  - Document ID: doc_23033, Positions: [0]
#  - Document ID: doc_23037, Positions: [3]
#  - Document ID: doc_23067, Positions: [3]
#  - Document ID: doc_23083, Positions: [21]
#  - Document ID: doc_23102, Positions: [4]
#  - Document ID: doc_23109, Positions: [17]
#  - Document ID: doc_23124, Positions: [4]
#  - Document ID: doc_23160, Positions: [2]
#  - Document ID: doc_23163, Positions: [15]
#  - Document ID: doc_23198, Positions: [6]
#  - Document ID: doc_23220, Positions: [9]
#  - Document ID: doc_23249, Positions: [25]
#  - Document ID: doc_23257, Positions: [6]
#  - Document ID: doc_23272, Positions: [7]
#  - Document ID: doc_23276, Positions: [21]
#  - Document ID: doc_23286, Positions: [6]
#  - Document ID: doc_23342, Positions: [13]
#  - Document ID: doc_23348, Positions: [5]
#  - Document ID: doc_23358, Positions: [1]
#  - Document ID: doc_23397, Positions: [1]
#  - Document ID: doc_23424, Positions: [20]
#  - Document ID: doc_23439, Positions: [10]
#  - Document ID: doc_23444, Positions: [1]
#  - Document ID: doc_23457, Positions: [2]
#  - Document ID: doc_23464, Positions: [11]
#  - Document ID: doc_23490, Positions: [2]
#  - Document ID: doc_23499, Positions: [3]
#  - Document ID: doc_23520, Positions: [17]
#  - Document ID: doc_23536, Positions: [5, 22]
#  - Document ID: doc_23539, Positions: [9]
#  - Document ID: doc_23540, Positions: [1]
#  - Document ID: doc_23542, Positions: [17]
#  - Document ID: doc_23574, Positions: [5]
#  - Document ID: doc_23577, Positions: [5]
#  - Document ID: doc_23629, Positions: [0]
#  - Document ID: doc_23630, Positions: [13]
#  - Document ID: doc_23638, Positions: [0, 4, 8]
#  - Document ID: doc_23655, Positions: [2]
#  - Document ID: doc_23662, Positions: [2]
#  - Document ID: doc_23687, Positions: [10]
#  - Document ID: doc_23691, Positions: [3]
#  - Document ID: doc_23701, Positions: [5]
#  - Document ID: doc_23734, Positions: [7]
#  - Document ID: doc_23752, Positions: [8]
#  - Document ID: doc_23780, Positions: [6]
#  - Document ID: doc_23813, Positions: [9]
#  - Document ID: doc_23847, Positions: [12]
#  - Document ID: doc_23853, Positions: [1]
#  - Document ID: doc_23862, Positions: [6]
#  - Document ID: doc_23924, Positions: [19]
#  - Document ID: doc_23944, Positions: [13]
#  - Document ID: doc_23946, Positions: [13]
#  - Document ID: doc_23947, Positions: [4]
#  - Document ID: doc_23958, Positions: [0, 15]
#  - Document ID: doc_23962, Positions: [8]
#  - Document ID: doc_23980, Positions: [2]
#  - Document ID: doc_23990, Positions: [0]
#  - Document ID: doc_24001, Positions: [1]
#  - Document ID: doc_24054, Positions: [8]
#  - Document ID: doc_24060, Positions: [2]
#  - Document ID: doc_24070, Positions: [3]
#  - Document ID: doc_24084, Positions: [6]
#  - Document ID: doc_24151, Positions: [4]
#  - Document ID: doc_24156, Positions: [8]
#  - Document ID: doc_24183, Positions: [1]
#  - Document ID: doc_24202, Positions: [25]
#  - Document ID: doc_24273, Positions: [1]
#  - Document ID: doc_24306, Positions: [0]
#  - Document ID: doc_24328, Positions: [0]
#  - Document ID: doc_24436, Positions: [7]
#  - Document ID: doc_24447, Positions: [2]
#  - Document ID: doc_24456, Positions: [1]
#  - Document ID: doc_24462, Positions: [2]
#  - Document ID: doc_24466, Positions: [9]
#  - Document ID: doc_24505, Positions: [13]
#  - Document ID: doc_24514, Positions: [7]
#  - Document ID: doc_24571, Positions: [17]
#  - Document ID: doc_24581, Positions: [6]
#  - Document ID: doc_24593, Positions: [6]
#  - Document ID: doc_24600, Positions: [4]
#  - Document ID: doc_24603, Positions: [1]
#  - Document ID: doc_24615, Positions: [3]
#  - Document ID: doc_24620, Positions: [3]
#  - Document ID: doc_24668, Positions: [2]
#  - Document ID: doc_24672, Positions: [24]
#  - Document ID: doc_24677, Positions: [17]
#  - Document ID: doc_24751, Positions: [12]
#  - Document ID: doc_24769, Positions: [19]
#  - Document ID: doc_24771, Positions: [0]
#  - Document ID: doc_24775, Positions: [5]
#  - Document ID: doc_24808, Positions: [1]
#  - Document ID: doc_24810, Positions: [7]
#  - Document ID: doc_24824, Positions: [17]
#  - Document ID: doc_24827, Positions: [7, 11]
#  - Document ID: doc_24840, Positions: [2]
#  - Document ID: doc_24849, Positions: [5]
#  - Document ID: doc_24878, Positions: [5]
#  - Document ID: doc_24880, Positions: [5]
#  - Document ID: doc_24884, Positions: [5]
#  - Document ID: doc_24961, Positions: [8]
#  - Document ID: doc_24994, Positions: [5, 8]
#  - Document ID: doc_25045, Positions: [1]
#  - Document ID: doc_25069, Positions: [19]
#  - Document ID: doc_25129, Positions: [16]
#  - Document ID: doc_25151, Positions: [6]
#  - Document ID: doc_25184, Positions: [2]
#  - Document ID: doc_25248, Positions: [0]
#  - Document ID: doc_25335, Positions: [0]
#  - Document ID: doc_25379, Positions: [8, 11]
#  - Document ID: doc_25380, Positions: [16]
#  - Document ID: doc_25401, Positions: [19]
#  - Document ID: doc_25482, Positions: [8]
#  - Document ID: doc_25498, Positions: [0]
#  - Document ID: doc_25505, Positions: [1]
#  - Document ID: doc_25516, Positions: [3, 15]
#  - Document ID: doc_25553, Positions: [14]
#  - Document ID: doc_25556, Positions: [14]
#  - Document ID: doc_25585, Positions: [4]
#  - Document ID: doc_25601, Positions: [8]
#  - Document ID: doc_25645, Positions: [2]
#  - Document ID: doc_25651, Positions: [2]
#  - Document ID: doc_25661, Positions: [4]
#  - Document ID: doc_25662, Positions: [4, 16]
#  - Document ID: doc_25663, Positions: [4]
#  - Document ID: doc_25677, Positions: [8]
#  - Document ID: doc_25711, Positions: [5]
#  - Document ID: doc_25742, Positions: [21]
#  - Document ID: doc_25767, Positions: [18]
#  - Document ID: doc_25770, Positions: [8]
#  - Document ID: doc_25772, Positions: [1]
#  - Document ID: doc_25774, Positions: [8]
#  - Document ID: doc_25808, Positions: [1]
#  - Document ID: doc_25859, Positions: [14]
#  - Document ID: doc_25866, Positions: [1, 11]
#  - Document ID: doc_25876, Positions: [1, 11]
#  - Document ID: doc_25884, Positions: [18]
#  - Document ID: doc_25904, Positions: [6]
#  - Document ID: doc_25927, Positions: [20]
#  - Document ID: doc_25934, Positions: [14]
#  - Document ID: doc_25954, Positions: [8]
#  - Document ID: doc_25955, Positions: [1]
#  - Document ID: doc_25996, Positions: [5]
#  - Document ID: doc_26066, Positions: [2]
#  - Document ID: doc_26090, Positions: [1]
#  - Document ID: doc_26122, Positions: [10]
#  - Document ID: doc_26260, Positions: [2]
#  - Document ID: doc_26303, Positions: [5]
#  - Document ID: doc_26314, Positions: [5]
#  - Document ID: doc_26330, Positions: [0]
#  - Document ID: doc_26344, Positions: [2]
#  - Document ID: doc_26350, Positions: [23]
#  - Document ID: doc_26363, Positions: [1]
#  - Document ID: doc_26377, Positions: [17]
#  - Document ID: doc_26401, Positions: [7]
#  - Document ID: doc_26405, Positions: [0]
#  - Document ID: doc_26424, Positions: [5]
#  - Document ID: doc_26533, Positions: [1]
#  - Document ID: doc_26577, Positions: [1]
#  - Document ID: doc_26581, Positions: [5]
#  - Document ID: doc_26632, Positions: [9]
#  - Document ID: doc_26636, Positions: [17]
#  - Document ID: doc_26654, Positions: [4]
#  - Document ID: doc_26668, Positions: [7]
#  - Document ID: doc_26681, Positions: [21]
#  - Document ID: doc_26697, Positions: [3]
#  - Document ID: doc_26702, Positions: [1]
#  - Document ID: doc_26704, Positions: [5]
#  - Document ID: doc_26712, Positions: [2]
#  - Document ID: doc_26744, Positions: [6]
#  - Document ID: doc_26755, Positions: [1]
#  - Document ID: doc_26757, Positions: [2]
#  - Document ID: doc_26758, Positions: [1]
#  - Document ID: doc_26767, Positions: [2]
#  - Document ID: doc_26773, Positions: [1]
#  - Document ID: doc_26776, Positions: [5]
#  - Document ID: doc_26784, Positions: [3]
#  - Document ID: doc_26785, Positions: [4]
#  - Document ID: doc_26795, Positions: [3]
#  - Document ID: doc_26796, Positions: [3]
#  - Document ID: doc_26797, Positions: [4]
#  - Document ID: doc_26804, Positions: [3]
#  - Document ID: doc_26860, Positions: [5]
#  - Document ID: doc_26889, Positions: [5]
#  - Document ID: doc_26895, Positions: [7]
#  - Document ID: doc_26898, Positions: [0]
#  - Document ID: doc_26922, Positions: [1]
#  - Document ID: doc_26945, Positions: [3]
#  - Document ID: doc_26951, Positions: [2]
#  - Document ID: doc_26952, Positions: [1]
#  - Document ID: doc_26964, Positions: [22]
#  - Document ID: doc_26967, Positions: [20]
#  - Document ID: doc_27043, Positions: [14]
#  - Document ID: doc_27050, Positions: [5]
#  - Document ID: doc_27054, Positions: [4, 12]
#  - Document ID: doc_27055, Positions: [16]
#  - Document ID: doc_27066, Positions: [3]
#  - Document ID: doc_27076, Positions: [1]
#  - Document ID: doc_27080, Positions: [15]
#  - Document ID: doc_27113, Positions: [0]
#  - Document ID: doc_27118, Positions: [16, 18]
#  - Document ID: doc_27149, Positions: [2]
#  - Document ID: doc_27179, Positions: [2]
#  - Document ID: doc_27188, Positions: [7]
#  - Document ID: doc_27190, Positions: [22]
#  - Document ID: doc_27193, Positions: [4]
#  - Document ID: doc_27225, Positions: [12]
#  - Document ID: doc_27229, Positions: [18]
#  - Document ID: doc_27230, Positions: [4]
#  - Document ID: doc_27303, Positions: [7, 27]
#  - Document ID: doc_27335, Positions: [7]
#  - Document ID: doc_27338, Positions: [2]
#  - Document ID: doc_27362, Positions: [3]
#  - Document ID: doc_27379, Positions: [8]
#  - Document ID: doc_27384, Positions: [8]
#  - Document ID: doc_27391, Positions: [1]
#  - Document ID: doc_27406, Positions: [8]
#  - Document ID: doc_27411, Positions: [1]
#  - Document ID: doc_27418, Positions: [1]
#  - Document ID: doc_27482, Positions: [6]
#  - Document ID: doc_27486, Positions: [2]
#  - Document ID: doc_27496, Positions: [4, 15]
#  - Document ID: doc_27505, Positions: [0]
#  - Document ID: doc_27530, Positions: [8]
#  - Document ID: doc_27561, Positions: [5]
#  - Document ID: doc_27586, Positions: [4]
#  - Document ID: doc_27616, Positions: [6]
#  - Document ID: doc_27636, Positions: [4]
#  - Document ID: doc_27648, Positions: [28]
#  - Document ID: doc_27682, Positions: [17]
#  - Document ID: doc_27689, Positions: [4]
#  - Document ID: doc_27692, Positions: [10]
#  - Document ID: doc_27700, Positions: [12]
#  - Document ID: doc_27708, Positions: [15]
#  - Document ID: doc_27732, Positions: [8]
#  - Document ID: doc_27745, Positions: [0]
#  - Document ID: doc_27749, Positions: [0]
#  - Document ID: doc_27778, Positions: [0]
#  - Document ID: doc_27787, Positions: [8]
#  - Document ID: doc_27801, Positions: [5]
#  - Document ID: doc_27890, Positions: [0]
#  - Document ID: doc_27894, Positions: [0]
#  - Document ID: doc_27908, Positions: [6]
#  - Document ID: doc_27916, Positions: [3]
#  - Document ID: doc_27923, Positions: [7]
#  - Document ID: doc_27937, Positions: [3, 8]
#  - Document ID: doc_27959, Positions: [5]
#  - Document ID: doc_27965, Positions: [13]
#  - Document ID: doc_27968, Positions: [3]
#  - Document ID: doc_27984, Positions: [9]
#  - Document ID: doc_27992, Positions: [8]
#  - Document ID: doc_28001, Positions: [16]
#  - Document ID: doc_28010, Positions: [3]
#  - Document ID: doc_28014, Positions: [19]
#  - Document ID: doc_28017, Positions: [7]
#  - Document ID: doc_28033, Positions: [3]
#  - Document ID: doc_28055, Positions: [4, 11]
#  - Document ID: doc_28057, Positions: [5]
#  - Document ID: doc_28062, Positions: [7]
#  - Document ID: doc_28069, Positions: [3]
#  - Document ID: doc_28070, Positions: [8]
#  - Document ID: doc_28072, Positions: [0]
#  - Document ID: doc_28095, Positions: [14]
#  - Document ID: doc_28138, Positions: [2]
#  - Document ID: doc_28164, Positions: [6]
#  - Document ID: doc_28168, Positions: [1]
#  - Document ID: doc_28207, Positions: [5]
#  - Document ID: doc_28209, Positions: [4]
#  - Document ID: doc_28253, Positions: [0, 15]
#  - Document ID: doc_28260, Positions: [2]
#  - Document ID: doc_28371, Positions: [13]
#  - Document ID: doc_28374, Positions: [10]
#  - Document ID: doc_28392, Positions: [8, 15]
#  - Document ID: doc_28413, Positions: [15]
#  - Document ID: doc_28417, Positions: [12]
#  - Document ID: doc_28419, Positions: [17]
#  - Document ID: doc_28440, Positions: [3]
#  - Document ID: doc_28455, Positions: [6]
#  - Document ID: doc_28464, Positions: [10]
#  - Document ID: doc_28472, Positions: [4]
#  - Document ID: doc_28473, Positions: [16]
#  - Document ID: doc_28477, Positions: [21]
#  - Document ID: doc_28484, Positions: [2]
#  - Document ID: doc_28488, Positions: [8]
#  - Document ID: doc_28502, Positions: [11]
#  - Document ID: doc_28519, Positions: [17]
#  - Document ID: doc_28607, Positions: [0]
#  - Document ID: doc_28619, Positions: [8]
#  - Document ID: doc_28621, Positions: [1]
#  - Document ID: doc_28633, Positions: [28]
#  - Document ID: doc_28690, Positions: [0]
#  - Document ID: doc_28723, Positions: [5]
#  - Document ID: doc_28724, Positions: [7]
#  - Document ID: doc_28728, Positions: [11]
#  - Document ID: doc_28749, Positions: [9]
#  - Document ID: doc_28755, Positions: [16]
#  - Document ID: doc_28764, Positions: [6]
#  - Document ID: doc_28766, Positions: [4, 6]
#  - Document ID: doc_28831, Positions: [11]
#  - Document ID: doc_28833, Positions: [0]
#  - Document ID: doc_28872, Positions: [5]
#  - Document ID: doc_28917, Positions: [2]
#  - Document ID: doc_28928, Positions: [19]
#  - Document ID: doc_28951, Positions: [0]
#  - Document ID: doc_28972, Positions: [4]
#  - Document ID: doc_28977, Positions: [32]
#  - Document ID: doc_28979, Positions: [33]
#  - Document ID: doc_28983, Positions: [31]
#  - Document ID: doc_28986, Positions: [1]
#  - Document ID: doc_28988, Positions: [31]
#  - Document ID: doc_28990, Positions: [21]
#  - Document ID: doc_28995, Positions: [1]
#  - Document ID: doc_28997, Positions: [0]
#  - Document ID: doc_29005, Positions: [1, 24]
#  - Document ID: doc_29010, Positions: [12]
#  - Document ID: doc_29023, Positions: [32]
#  - Document ID: doc_29035, Positions: [0]
#  - Document ID: doc_29039, Positions: [32]
#  - Document ID: doc_29053, Positions: [30]
#  - Document ID: doc_29057, Positions: [1]
#  - Document ID: doc_29086, Positions: [8]
#  - Document ID: doc_29100, Positions: [0]
#  - Document ID: doc_29109, Positions: [11]
#  - Document ID: doc_29115, Positions: [9, 19]
#  - Document ID: doc_29130, Positions: [1]
#  - Document ID: doc_29134, Positions: [5]
#  - Document ID: doc_29135, Positions: [12, 22]
#  - Document ID: doc_29148, Positions: [2]
#  - Document ID: doc_29154, Positions: [6]
#  - Document ID: doc_29158, Positions: [2]
#  - Document ID: doc_29163, Positions: [14, 26]
#  - Document ID: doc_29182, Positions: [5, 20]
#  - Document ID: doc_29247, Positions: [2]
#  - Document ID: doc_29265, Positions: [1]
#  - Document ID: doc_29276, Positions: [3]
#  - Document ID: doc_29291, Positions: [17]
#  - Document ID: doc_29344, Positions: [14]
#  - Document ID: doc_29355, Positions: [1]
#  - Document ID: doc_29370, Positions: [17]
#  - Document ID: doc_29374, Positions: [3, 11]
#  - Document ID: doc_29383, Positions: [1, 10]
#  - Document ID: doc_29446, Positions: [8]
#  - Document ID: doc_29462, Positions: [0]
#  - Document ID: doc_29465, Positions: [2]
#  - Document ID: doc_29481, Positions: [12, 21]
#  - Document ID: doc_29510, Positions: [3]
#  - Document ID: doc_29514, Positions: [0]
#  - Document ID: doc_29517, Positions: [20]
#  - Document ID: doc_29518, Positions: [1]
#  - Document ID: doc_29521, Positions: [0]
#  - Document ID: doc_29529, Positions: [6, 10]
#  - Document ID: doc_29545, Positions: [2]
#  - Document ID: doc_29563, Positions: [4]
#  - Document ID: doc_29565, Positions: [2]
#  - Document ID: doc_29568, Positions: [1]
#  - Document ID: doc_29599, Positions: [2]
#  - Document ID: doc_29630, Positions: [6]
#  - Document ID: doc_29645, Positions: [2]
#  - Document ID: doc_29702, Positions: [19]
#  - Document ID: doc_29704, Positions: [12]
#  - Document ID: doc_29728, Positions: [4]
#  - Document ID: doc_29778, Positions: [7]
#  - Document ID: doc_29815, Positions: [9]
#  - Document ID: doc_29886, Positions: [11]
#  - Document ID: doc_29912, Positions: [8]
#  - Document ID: doc_29914, Positions: [4]
#  - Document ID: doc_29982, Positions: [1]
#  - Document ID: doc_29983, Positions: [4]
#  - Document ID: doc_29991, Positions: [6]
#  - Document ID: doc_30007, Positions: [3]
#  - Document ID: doc_30019, Positions: [14]
#  - Document ID: doc_30044, Positions: [18]
#  - Document ID: doc_30051, Positions: [3, 11]
#  - Document ID: doc_30077, Positions: [21]
#  - Document ID: doc_30080, Positions: [6]
#  - Document ID: doc_30112, Positions: [1, 3]
#  - Document ID: doc_30122, Positions: [0, 2]
#  - Document ID: doc_30164, Positions: [3, 5]
#  - Document ID: doc_30210, Positions: [3]
#  - Document ID: doc_30230, Positions: [2]
#  - Document ID: doc_30290, Positions: [5, 18]
#  - Document ID: doc_30304, Positions: [0]
#  - Document ID: doc_30309, Positions: [7]
#  - Document ID: doc_30330, Positions: [1]
#  - Document ID: doc_30338, Positions: [8]
#  - Document ID: doc_30394, Positions: [5]
#  - Document ID: doc_30419, Positions: [3]
#  - Document ID: doc_30422, Positions: [0]
#  - Document ID: doc_30423, Positions: [3]
#  - Document ID: doc_30435, Positions: [11]
#  - Document ID: doc_30452, Positions: [10]
#  - Document ID: doc_30457, Positions: [4]
#  - Document ID: doc_30463, Positions: [1]
#  - Document ID: doc_30465, Positions: [3]
#  - Document ID: doc_30486, Positions: [0]
#  - Document ID: doc_30529, Positions: [4]
#  - Document ID: doc_30530, Positions: [3]
#  - Document ID: doc_30537, Positions: [7, 14]
#  - Document ID: doc_30611, Positions: [2]
#  - Document ID: doc_30619, Positions: [3]
#  - Document ID: doc_30682, Positions: [3]
#  - Document ID: doc_30696, Positions: [10]
#  - Document ID: doc_30702, Positions: [6]
#  - Document ID: doc_30706, Positions: [12]
#  - Document ID: doc_30722, Positions: [20]
#  - Document ID: doc_30729, Positions: [31]
#  - Document ID: doc_30744, Positions: [7]
#  - Document ID: doc_30746, Positions: [7]
#  - Document ID: doc_30768, Positions: [13]
#  - Document ID: doc_30772, Positions: [1]
#  - Document ID: doc_30777, Positions: [2]
#  - Document ID: doc_30785, Positions: [4]
#  - Document ID: doc_30788, Positions: [13]
#  - Document ID: doc_30804, Positions: [14]
#  - Document ID: doc_30820, Positions: [0]
#  - Document ID: doc_30854, Positions: [23]
#  - Document ID: doc_30875, Positions: [11]
#  - Document ID: doc_30897, Positions: [1]
#  - Document ID: doc_30939, Positions: [13]
#  - Document ID: doc_30952, Positions: [5]
#  - Document ID: doc_30971, Positions: [4]
#  - Document ID: doc_30995, Positions: [9]
#  - Document ID: doc_31021, Positions: [6]
#  - Document ID: doc_31027, Positions: [12]
#  - Document ID: doc_31029, Positions: [13]
#  - Document ID: doc_31066, Positions: [13]
#  - Document ID: doc_31073, Positions: [7]
#  - Document ID: doc_31098, Positions: [2]
#  - Document ID: doc_31116, Positions: [4]
#  - Document ID: doc_31142, Positions: [19]
#  - Document ID: doc_31183, Positions: [5]
#  - Document ID: doc_31188, Positions: [0]
#  - Document ID: doc_31196, Positions: [3]
#  - Document ID: doc_31228, Positions: [9]
#  - Document ID: doc_31238, Positions: [4]
#  - Document ID: doc_31252, Positions: [15]
#  - Document ID: doc_31266, Positions: [17]
#  - Document ID: doc_31267, Positions: [3]
#  - Document ID: doc_31302, Positions: [7]
#  - Document ID: doc_31323, Positions: [25]
#  - Document ID: doc_31329, Positions: [17]
#  - Document ID: doc_31330, Positions: [6]
#  - Document ID: doc_31331, Positions: [9]
#  - Document ID: doc_31349, Positions: [1, 11]
#  - Document ID: doc_31358, Positions: [6]
#  - Document ID: doc_31359, Positions: [8]
#  - Document ID: doc_31398, Positions: [1]
#  - Document ID: doc_31418, Positions: [14]
#  - Document ID: doc_31431, Positions: [3]
#  - Document ID: doc_31449, Positions: [5]
#  - Document ID: doc_31467, Positions: [4]
#  - Document ID: doc_31469, Positions: [4]
#  - Document ID: doc_31483, Positions: [15]
#  - Document ID: doc_31488, Positions: [7]
#  - Document ID: doc_31489, Positions: [2]
#  - Document ID: doc_31491, Positions: [4]
#  - Document ID: doc_31494, Positions: [13]
#  - Document ID: doc_31499, Positions: [1]
#  - Document ID: doc_31505, Positions: [3]
#  - Document ID: doc_31510, Positions: [0]
#  - Document ID: doc_31520, Positions: [4, 7]
#  - Document ID: doc_31557, Positions: [12]
#  - Document ID: doc_31560, Positions: [1]
#  - Document ID: doc_31568, Positions: [3, 6]
#  - Document ID: doc_31626, Positions: [4, 13]
#  - Document ID: doc_31627, Positions: [4]
#  - Document ID: doc_31682, Positions: [0]
#  - Document ID: doc_31685, Positions: [1]
#  - Document ID: doc_31693, Positions: [1]
#  - Document ID: doc_31704, Positions: [2]
#  - Document ID: doc_31710, Positions: [3]
#  - Document ID: doc_31718, Positions: [3]
#  - Document ID: doc_31748, Positions: [22]
#  - Document ID: doc_31749, Positions: [1]
#  - Document ID: doc_31767, Positions: [9]
#  - Document ID: doc_31779, Positions: [12]
#  - Document ID: doc_31785, Positions: [9]
#  - Document ID: doc_31812, Positions: [0]
#  - Document ID: doc_31839, Positions: [3]
#  - Document ID: doc_31876, Positions: [0]
#  - Document ID: doc_31907, Positions: [12]
#  - Document ID: doc_31955, Positions: [19]
#  - Document ID: doc_31964, Positions: [5]
#  - Document ID: doc_32008, Positions: [0]
#  - Document ID: doc_32010, Positions: [0]
#  - Document ID: doc_32013, Positions: [0, 5]
#  - Document ID: doc_32015, Positions: [4]
#  - Document ID: doc_32036, Positions: [1]
#  - Document ID: doc_32046, Positions: [1]
#  - Document ID: doc_32074, Positions: [10]
#  - Document ID: doc_32088, Positions: [0]
#  - Document ID: doc_32090, Positions: [2]
#  - Document ID: doc_32108, Positions: [6]
#  - Document ID: doc_32118, Positions: [1]
#  - Document ID: doc_32119, Positions: [0]
#  - Document ID: doc_32124, Positions: [16]
#  - Document ID: doc_32162, Positions: [0]
#  - Document ID: doc_32181, Positions: [4]
#  - Document ID: doc_32200, Positions: [27]
#  - Document ID: doc_32203, Positions: [5]
#  - Document ID: doc_32211, Positions: [19]
#  - Document ID: doc_32257, Positions: [0]
#  - Document ID: doc_32295, Positions: [0]
#  - Document ID: doc_32315, Positions: [1]
#  - Document ID: doc_32354, Positions: [20]
#  - Document ID: doc_32377, Positions: [3, 13]
#  - Document ID: doc_32402, Positions: [5]
#  - Document ID: doc_32430, Positions: [5, 15]
#  - Document ID: doc_32431, Positions: [6]
#  - Document ID: doc_32473, Positions: [4]
#  - Document ID: doc_32494, Positions: [2]
#  - Document ID: doc_32511, Positions: [20]
#  - Document ID: doc_32517, Positions: [13]
#  - Document ID: doc_32529, Positions: [1]
#  - Document ID: doc_32541, Positions: [19]
#  - Document ID: doc_32543, Positions: [2, 14]
#  - Document ID: doc_32564, Positions: [17]
#  - Document ID: doc_32567, Positions: [10]
#  - Document ID: doc_32574, Positions: [18]
#  - Document ID: doc_32586, Positions: [5]
#  - Document ID: doc_32600, Positions: [17]
#  - Document ID: doc_32623, Positions: [2]
#  - Document ID: doc_32628, Positions: [5]
#  - Document ID: doc_32629, Positions: [5, 21]
#  - Document ID: doc_32647, Positions: [0]
#  - Document ID: doc_32659, Positions: [0]
#  - Document ID: doc_32726, Positions: [6]
#  - Document ID: doc_32810, Positions: [4]
#  - Document ID: doc_32833, Positions: [4]
#  - Document ID: doc_32837, Positions: [1]
#  - Document ID: doc_32850, Positions: [6]
#  - Document ID: doc_32864, Positions: [1]
#  - Document ID: doc_32867, Positions: [0]
#  - Document ID: doc_32932, Positions: [13]
#  - Document ID: doc_32956, Positions: [8]
#  - Document ID: doc_32994, Positions: [1]
#  - Document ID: doc_32995, Positions: [23]
#  - Document ID: doc_33016, Positions: [1]
#  - Document ID: doc_33043, Positions: [5]
#  - Document ID: doc_33067, Positions: [7]
#  - Document ID: doc_33070, Positions: [1]
#  - Document ID: doc_33116, Positions: [12]
#  - Document ID: doc_33125, Positions: [13]
#  - Document ID: doc_33131, Positions: [0]
#  - Document ID: doc_33140, Positions: [12]
#  - Document ID: doc_33156, Positions: [8]
#  - Document ID: doc_33175, Positions: [13]
#  - Document ID: doc_33188, Positions: [3]
#  - Document ID: doc_33232, Positions: [6]
#  - Document ID: doc_33251, Positions: [4]
#  - Document ID: doc_33274, Positions: [22]
#  - Document ID: doc_33284, Positions: [0]
#  - Document ID: doc_33299, Positions: [0, 5]
#  - Document ID: doc_33396, Positions: [5]
#  - Document ID: doc_33408, Positions: [3]
#  - Document ID: doc_33413, Positions: [14]
#  - Document ID: doc_33431, Positions: [14]
#  - Document ID: doc_33443, Positions: [15]
#  - Document ID: doc_33453, Positions: [4]
#  - Document ID: doc_33534, Positions: [8]
#  - Document ID: doc_33558, Positions: [2]
#  - Document ID: doc_33573, Positions: [1]
#  - Document ID: doc_33578, Positions: [1]
#  - Document ID: doc_33596, Positions: [0]
#  - Document ID: doc_33620, Positions: [2]
#  - Document ID: doc_33632, Positions: [14]
#  - Document ID: doc_33636, Positions: [17]
#  - Document ID: doc_33641, Positions: [23]
#  - Document ID: doc_33686, Positions: [10]
#  - Document ID: doc_33737, Positions: [16]
#  - Document ID: doc_33742, Positions: [1]
#  - Document ID: doc_33750, Positions: [7]
#  - Document ID: doc_33876, Positions: [0]
#  - Document ID: doc_33879, Positions: [0]
#  - Document ID: doc_33893, Positions: [12]
#  - Document ID: doc_33904, Positions: [0, 5]
#  - Document ID: doc_33915, Positions: [10]
#  - Document ID: doc_33992, Positions: [5]
#  - Document ID: doc_34018, Positions: [14]
#  - Document ID: doc_34068, Positions: [1]
#  - Document ID: doc_34072, Positions: [5]
#  - Document ID: doc_34145, Positions: [14]
#  - Document ID: doc_34156, Positions: [4]
#  - Document ID: doc_34188, Positions: [3]
#  - Document ID: doc_34194, Positions: [14]
#  - Document ID: doc_34205, Positions: [2]
#  - Document ID: doc_34211, Positions: [19]
#  - Document ID: doc_34213, Positions: [21]
#  - Document ID: doc_34214, Positions: [20]
#  - Document ID: doc_34215, Positions: [20]
#  - Document ID: doc_34217, Positions: [21]
#  - Document ID: doc_34220, Positions: [20]
#  - Document ID: doc_34221, Positions: [20]
#  - Document ID: doc_34224, Positions: [19]
#  - Document ID: doc_34226, Positions: [21]
#  - Document ID: doc_34227, Positions: [20]
#  - Document ID: doc_34228, Positions: [21]
#  - Document ID: doc_34232, Positions: [20]
#  - Document ID: doc_34235, Positions: [20]
#  - Document ID: doc_34236, Positions: [2]
#  - Document ID: doc_34254, Positions: [15]
#  - Document ID: doc_34281, Positions: [0]
#  - Document ID: doc_34286, Positions: [1]
#  - Document ID: doc_34290, Positions: [8]
#  - Document ID: doc_34292, Positions: [10]
#  - Document ID: doc_34305, Positions: [10]
#  - Document ID: doc_34312, Positions: [18]
#  - Document ID: doc_34317, Positions: [15]
#  - Document ID: doc_34322, Positions: [16]
#  - Document ID: doc_34331, Positions: [19]
#  - Document ID: doc_34336, Positions: [1]
#  - Document ID: doc_34350, Positions: [0]
#  - Document ID: doc_34383, Positions: [2]
#  - Document ID: doc_34393, Positions: [17]
#  - Document ID: doc_34418, Positions: [22]
#  - Document ID: doc_34421, Positions: [6]
#  - Document ID: doc_34457, Positions: [3]
#  - Document ID: doc_34493, Positions: [2]
#  - Document ID: doc_34495, Positions: [15]
#  - Document ID: doc_34556, Positions: [6]
#  - Document ID: doc_34576, Positions: [0]
#  - Document ID: doc_34596, Positions: [5]
#  - Document ID: doc_34604, Positions: [6]
#  - Document ID: doc_34627, Positions: [18]
#  - Document ID: doc_34650, Positions: [8]
#  - Document ID: doc_34728, Positions: [1]
#  - Document ID: doc_34729, Positions: [0, 5]
#  - Document ID: doc_34770, Positions: [10]
#  - Document ID: doc_34775, Positions: [10]
#  - Document ID: doc_34799, Positions: [3]
#  - Document ID: doc_34805, Positions: [0]
#  - Document ID: doc_34840, Positions: [3]
#  - Document ID: doc_34869, Positions: [0, 2, 20]
#  - Document ID: doc_34870, Positions: [1]
#  - Document ID: doc_34902, Positions: [1]
#  - Document ID: doc_34915, Positions: [9]
#  - Document ID: doc_35027, Positions: [12]
#  - Document ID: doc_35054, Positions: [23]
#  - Document ID: doc_35055, Positions: [17]
#  - Document ID: doc_35074, Positions: [6]
#  - Document ID: doc_35081, Positions: [2]
#  - Document ID: doc_35149, Positions: [11]
#  - Document ID: doc_35161, Positions: [0]
#  - Document ID: doc_35163, Positions: [17]
#  - Document ID: doc_35171, Positions: [19]
#  - Document ID: doc_35172, Positions: [3]
#  - Document ID: doc_35193, Positions: [4]
#  - Document ID: doc_35220, Positions: [7]
#  - Document ID: doc_35242, Positions: [17]
#  - Document ID: doc_35243, Positions: [3]
#  - Document ID: doc_35246, Positions: [16]
#  - Document ID: doc_35249, Positions: [2]
#  - Document ID: doc_35250, Positions: [2]
#  - Document ID: doc_35251, Positions: [2]
#  - Document ID: doc_35252, Positions: [2]
#  - Document ID: doc_35255, Positions: [2]
#  - Document ID: doc_35256, Positions: [2]
#  - Document ID: doc_35257, Positions: [2]
#  - Document ID: doc_35259, Positions: [2]
#  - Document ID: doc_35260, Positions: [2]
#  - Document ID: doc_35261, Positions: [2]
#  - Document ID: doc_35263, Positions: [1]
#  - Document ID: doc_35264, Positions: [2]
#  - Document ID: doc_35265, Positions: [2]
#  - Document ID: doc_35266, Positions: [2]
#  - Document ID: doc_35267, Positions: [2]
#  - Document ID: doc_35268, Positions: [2]
#  - Document ID: doc_35270, Positions: [2]
#  - Document ID: doc_35272, Positions: [2]
#  - Document ID: doc_35273, Positions: [2]
#  - Document ID: doc_35301, Positions: [0]
#  - Document ID: doc_35309, Positions: [1]
#  - Document ID: doc_35312, Positions: [5]
#  - Document ID: doc_35315, Positions: [18]
#  - Document ID: doc_35320, Positions: [1]
#  - Document ID: doc_35335, Positions: [1]
#  - Document ID: doc_35367, Positions: [0, 12]
#  - Document ID: doc_35385, Positions: [5]
#  - Document ID: doc_35404, Positions: [12]
#  - Document ID: doc_35411, Positions: [2]
#  - Document ID: doc_35413, Positions: [1]
#  - Document ID: doc_35434, Positions: [9]
#  - Document ID: doc_35438, Positions: [0]
#  - Document ID: doc_35447, Positions: [3]
#  - Document ID: doc_35507, Positions: [9]
#  - Document ID: doc_35513, Positions: [2, 6]
#  - Document ID: doc_35528, Positions: [2]
#  - Document ID: doc_35577, Positions: [2, 10]
#  - Document ID: doc_35586, Positions: [0]
#  - Document ID: doc_35590, Positions: [3]
#  - Document ID: doc_35604, Positions: [21]
#  - Document ID: doc_35619, Positions: [15]
#  - Document ID: doc_35655, Positions: [0]
#  - Document ID: doc_35680, Positions: [0]
#  - Document ID: doc_35703, Positions: [0]
#  - Document ID: doc_35715, Positions: [0]
#  - Document ID: doc_35716, Positions: [2, 22]
#  - Document ID: doc_35718, Positions: [12]
#  - Document ID: doc_35730, Positions: [7]
#  - Document ID: doc_35731, Positions: [1]
#  - Document ID: doc_35738, Positions: [5]
#  - Document ID: doc_35742, Positions: [6]
#  - Document ID: doc_35746, Positions: [11]
#  - Document ID: doc_35754, Positions: [3]
#  - Document ID: doc_35767, Positions: [9]
#  - Document ID: doc_35768, Positions: [4]
#  - Document ID: doc_35825, Positions: [0]
#  - Document ID: doc_35867, Positions: [21]
#  - Document ID: doc_35879, Positions: [7]
#  - Document ID: doc_35882, Positions: [12]
#  - Document ID: doc_35908, Positions: [22]
#  - Document ID: doc_35923, Positions: [6]
#  - Document ID: doc_35939, Positions: [4]
#  - Document ID: doc_35945, Positions: [0]
#  - Document ID: doc_35950, Positions: [15]
#  - Document ID: doc_35956, Positions: [10]
#  - Document ID: doc_35966, Positions: [4]
#  - Document ID: doc_35972, Positions: [7]
#  - Document ID: doc_35977, Positions: [5]
#  - Document ID: doc_36000, Positions: [2]
#  - Document ID: doc_36032, Positions: [10]
#  - Document ID: doc_36058, Positions: [15]
#  - Document ID: doc_36059, Positions: [15]
#  - Document ID: doc_36060, Positions: [16]
#  - Document ID: doc_36061, Positions: [15]
#  - Document ID: doc_36062, Positions: [15]
#  - Document ID: doc_36064, Positions: [19]
#  - Document ID: doc_36065, Positions: [13]
#  - Document ID: doc_36081, Positions: [0]
#  - Document ID: doc_36091, Positions: [0]
#  - Document ID: doc_36103, Positions: [0]
#  - Document ID: doc_36127, Positions: [2]
#  - Document ID: doc_36133, Positions: [0]
#  - Document ID: doc_36147, Positions: [19]
#  - Document ID: doc_36174, Positions: [3]
#  - Document ID: doc_36196, Positions: [4]
#  - Document ID: doc_36211, Positions: [3]
#  - Document ID: doc_36241, Positions: [1]
#  - Document ID: doc_36267, Positions: [1]
#  - Document ID: doc_36270, Positions: [4]
#  - Document ID: doc_36271, Positions: [0]
#  - Document ID: doc_36278, Positions: [0]
#  - Document ID: doc_36286, Positions: [5]
#  - Document ID: doc_36311, Positions: [11]
#  - Document ID: doc_36329, Positions: [11]
#  - Document ID: doc_36331, Positions: [3]
#  - Document ID: doc_36344, Positions: [24]
#  - Document ID: doc_36387, Positions: [19]
#  - Document ID: doc_36393, Positions: [0]
#  - Document ID: doc_36408, Positions: [0]
#  - Document ID: doc_36410, Positions: [1]
#  - Document ID: doc_36446, Positions: [12]
#  - Document ID: doc_36457, Positions: [0]
#  - Document ID: doc_36461, Positions: [12]
#  - Document ID: doc_36465, Positions: [15]
#  - Document ID: doc_36466, Positions: [15]
#  - Document ID: doc_36469, Positions: [15]
#  - Document ID: doc_36474, Positions: [15]
#  - Document ID: doc_36476, Positions: [15]
#  - Document ID: doc_36479, Positions: [16]
#  - Document ID: doc_36482, Positions: [16]
#  - Document ID: doc_36642, Positions: [4]
#  - Document ID: doc_36667, Positions: [3]
#  - Document ID: doc_36674, Positions: [10]
#  - Document ID: doc_36682, Positions: [11]
#  - Document ID: doc_36688, Positions: [15]
#  - Document ID: doc_36696, Positions: [7, 9]
#  - Document ID: doc_36734, Positions: [2]
#  - Document ID: doc_36798, Positions: [22]
#  - Document ID: doc_36803, Positions: [15]
#  - Document ID: doc_36830, Positions: [2, 7]
#  - Document ID: doc_36834, Positions: [19]
#  - Document ID: doc_36838, Positions: [23]
#  - Document ID: doc_36840, Positions: [2]
#  - Document ID: doc_36856, Positions: [2]
#  - Document ID: doc_36858, Positions: [10]
#  - Document ID: doc_36865, Positions: [10, 15]
#  - Document ID: doc_36869, Positions: [8]
#  - Document ID: doc_36881, Positions: [19]
#  - Document ID: doc_36884, Positions: [19]
#  - Document ID: doc_36886, Positions: [6]
#  - Document ID: doc_36902, Positions: [2]
#  - Document ID: doc_36919, Positions: [4]
#  - Document ID: doc_36945, Positions: [2]
#  - Document ID: doc_36957, Positions: [25]
#  - Document ID: doc_36986, Positions: [8]
#  - Document ID: doc_36992, Positions: [7]
#  - Document ID: doc_36994, Positions: [16]
#  - Document ID: doc_37000, Positions: [10]
#  - Document ID: doc_37001, Positions: [10]
#  - Document ID: doc_37009, Positions: [6]
#  - Document ID: doc_37011, Positions: [9]
#  - Document ID: doc_37054, Positions: [4, 15]
#  - Document ID: doc_37057, Positions: [17]
#  - Document ID: doc_37058, Positions: [9]
#  - Document ID: doc_37062, Positions: [5]
#  - Document ID: doc_37065, Positions: [9]
#  - Document ID: doc_37077, Positions: [5]
#  - Document ID: doc_37090, Positions: [5, 11, 18]
#  - Document ID: doc_37092, Positions: [0]
#  - Document ID: doc_37094, Positions: [7]
#  - Document ID: doc_37101, Positions: [2]
#  - Document ID: doc_37117, Positions: [3, 9, 16]
#  - Document ID: doc_37119, Positions: [3]
#  - Document ID: doc_37136, Positions: [21]
#  - Document ID: doc_37176, Positions: [20]
#  - Document ID: doc_37187, Positions: [10]
#  - Document ID: doc_37209, Positions: [2, 8, 15]
#  - Document ID: doc_37219, Positions: [2, 8, 15]
#  - Document ID: doc_37232, Positions: [4, 10, 17]
#  - Document ID: doc_37241, Positions: [1, 7, 14]
#  - Document ID: doc_37257, Positions: [5, 26]
#  - Document ID: doc_37268, Positions: [2]
#  - Document ID: doc_37270, Positions: [1, 13, 21]
#  - Document ID: doc_37306, Positions: [4]
#  - Document ID: doc_37307, Positions: [3]
#  - Document ID: doc_37332, Positions: [3]
#  - Document ID: doc_37337, Positions: [10]
#  - Document ID: doc_37338, Positions: [9]
#  - Document ID: doc_37345, Positions: [10]
#  - Document ID: doc_37346, Positions: [9]
#  - Document ID: doc_37365, Positions: [1]
#  - Document ID: doc_37376, Positions: [0]
#  - Document ID: doc_37405, Positions: [3]
#  - Document ID: doc_37414, Positions: [3]
#  - Document ID: doc_37437, Positions: [2]
#  - Document ID: doc_37441, Positions: [6, 16]
#  - Document ID: doc_37444, Positions: [5]
#  - Document ID: doc_37493, Positions: [10]
#  - Document ID: doc_37534, Positions: [10]
#  - Document ID: doc_37558, Positions: [6]
#  - Document ID: doc_37575, Positions: [4]
#  - Document ID: doc_37620, Positions: [11]
#  - Document ID: doc_37638, Positions: [9]
#  - Document ID: doc_37651, Positions: [7]
#  - Document ID: doc_37665, Positions: [2]
#  - Document ID: doc_37676, Positions: [0]
#  - Document ID: doc_37683, Positions: [3]
#  - Document ID: doc_37693, Positions: [8]
#  - Document ID: doc_37696, Positions: [6]
#  - Document ID: doc_37698, Positions: [0]
#  - Document ID: doc_37699, Positions: [4]
#  - Document ID: doc_37721, Positions: [2]
#  - Document ID: doc_37737, Positions: [3]
#  - Document ID: doc_37793, Positions: [8]
#  - Document ID: doc_37836, Positions: [0]
#  - Document ID: doc_37859, Positions: [5]
#  - Document ID: doc_37865, Positions: [4]
#  - Document ID: doc_37875, Positions: [4]
#  - Document ID: doc_37881, Positions: [3, 12]
#  - Document ID: doc_37891, Positions: [5]
#  - Document ID: doc_37919, Positions: [1]
#  - Document ID: doc_37933, Positions: [1]
#  - Document ID: doc_37937, Positions: [0]
#  - Document ID: doc_37942, Positions: [7]
#  - Document ID: doc_37997, Positions: [5]
#  - Document ID: doc_38042, Positions: [13]
#  - Document ID: doc_38065, Positions: [3]
#  - Document ID: doc_38068, Positions: [6]
#  - Document ID: doc_38078, Positions: [14]
#  - Document ID: doc_38095, Positions: [17]
#  - Document ID: doc_38105, Positions: [19]
#  - Document ID: doc_38119, Positions: [5]
#  - Document ID: doc_38158, Positions: [0]
#  - Document ID: doc_38170, Positions: [0, 20]
#  - Document ID: doc_38206, Positions: [4]
#  - Document ID: doc_38214, Positions: [0]
#  - Document ID: doc_38236, Positions: [2]
#  - Document ID: doc_38240, Positions: [1]
#  - Document ID: doc_38249, Positions: [4]
#  - Document ID: doc_38264, Positions: [2, 8]
#  - Document ID: doc_38266, Positions: [0]
#  - Document ID: doc_38282, Positions: [0]
#  - Document ID: doc_38305, Positions: [3]
#  - Document ID: doc_38314, Positions: [4, 9]
#  - Document ID: doc_38381, Positions: [1]
#  - Document ID: doc_38417, Positions: [11]
#  - Document ID: doc_38422, Positions: [1]
#  - Document ID: doc_38448, Positions: [3, 12]
#  - Document ID: doc_38452, Positions: [0]
#  - Document ID: doc_38458, Positions: [12]
#  - Document ID: doc_38462, Positions: [5]
#  - Document ID: doc_38474, Positions: [11]
#  - Document ID: doc_38492, Positions: [13]
#  - Document ID: doc_38538, Positions: [12]
#  - Document ID: doc_38576, Positions: [3]
#  - Document ID: doc_38580, Positions: [23]
#  - Document ID: doc_38581, Positions: [6]
#  - Document ID: doc_38593, Positions: [21]
#  - Document ID: doc_38602, Positions: [4]
#  - Document ID: doc_38642, Positions: [1]
#  - Document ID: doc_38645, Positions: [24]
#  - Document ID: doc_38647, Positions: [18]
#  - Document ID: doc_38648, Positions: [10]
#  - Document ID: doc_38666, Positions: [11]
#  - Document ID: doc_38730, Positions: [5]
#  - Document ID: doc_38758, Positions: [1, 5]
#  - Document ID: doc_38760, Positions: [6]
#  - Document ID: doc_38783, Positions: [13]
#  - Document ID: doc_38787, Positions: [14]
#  - Document ID: doc_38804, Positions: [8]
#  - Document ID: doc_38807, Positions: [1]
#  - Document ID: doc_38815, Positions: [14]
#  - Document ID: doc_38834, Positions: [17]
#  - Document ID: doc_38838, Positions: [17]
#  - Document ID: doc_38843, Positions: [2]
#  - Document ID: doc_38859, Positions: [1]
#  - Document ID: doc_38874, Positions: [8]
#  - Document ID: doc_38891, Positions: [1]
#  - Document ID: doc_38902, Positions: [5]
#  - Document ID: doc_38921, Positions: [2]
#  - Document ID: doc_38945, Positions: [3]
#  - Document ID: doc_38950, Positions: [5]
#  - Document ID: doc_38954, Positions: [6]
#  - Document ID: doc_38971, Positions: [0, 8]
#  - Document ID: doc_38999, Positions: [7]
#  - Document ID: doc_39003, Positions: [23]
#  - Document ID: doc_39014, Positions: [7]
#  - Document ID: doc_39031, Positions: [5]
#  - Document ID: doc_39042, Positions: [0]
#  - Document ID: doc_39043, Positions: [7]
#  - Document ID: doc_39044, Positions: [1]
#  - Document ID: doc_39063, Positions: [5]
#  - Document ID: doc_39094, Positions: [17]
#  - Document ID: doc_39111, Positions: [0]
#  - Document ID: doc_39148, Positions: [16]
#  - Document ID: doc_39151, Positions: [0]
#  - Document ID: doc_39166, Positions: [4]
#  - Document ID: doc_39173, Positions: [7]
#  - Document ID: doc_39183, Positions: [1]
#  - Document ID: doc_39213, Positions: [22]
#  - Document ID: doc_39214, Positions: [2]
#  - Document ID: doc_39228, Positions: [0]
#  - Document ID: doc_39317, Positions: [0]
#  - Document ID: doc_39320, Positions: [2]
#  - Document ID: doc_39351, Positions: [15]
#  - Document ID: doc_39361, Positions: [2]
#  - Document ID: doc_39374, Positions: [12]
#  - Document ID: doc_39396, Positions: [1]
#  - Document ID: doc_39420, Positions: [2]
#  - Document ID: doc_39457, Positions: [12]
#  - Document ID: doc_39462, Positions: [3]
#  - Document ID: doc_39467, Positions: [1]
#  - Document ID: doc_39474, Positions: [4]
#  - Document ID: doc_39500, Positions: [11]
#  - Document ID: doc_39501, Positions: [1, 9]
#  - Document ID: doc_39522, Positions: [10]
#  - Document ID: doc_39532, Positions: [2]
#  - Document ID: doc_39549, Positions: [0]
#  - Document ID: doc_39624, Positions: [2]
#  - Document ID: doc_39627, Positions: [0]
#  - Document ID: doc_39631, Positions: [1]
#  - Document ID: doc_39694, Positions: [15]
#  - Document ID: doc_39710, Positions: [2]
#  - Document ID: doc_39748, Positions: [10]
#  - Document ID: doc_39752, Positions: [1]
#  - Document ID: doc_39762, Positions: [2]
#  - Document ID: doc_39779, Positions: [1, 3]
#  - Document ID: doc_39782, Positions: [1]
#  - Document ID: doc_39793, Positions: [13]
#  - Document ID: doc_39800, Positions: [2]
#  - Document ID: doc_39801, Positions: [20]
#  - Document ID: doc_39819, Positions: [2]
#  - Document ID: doc_39849, Positions: [10]
#  - Document ID: doc_39869, Positions: [4]
#  - Document ID: doc_39883, Positions: [15]
#  - Document ID: doc_39897, Positions: [7]
#  - Document ID: doc_39908, Positions: [0]
#  - Document ID: doc_39942, Positions: [1]
#  - Document ID: doc_39946, Positions: [3]
#  - Document ID: doc_39955, Positions: [1]
#  - Document ID: doc_39978, Positions: [2]
#  - Document ID: doc_39992, Positions: [3]
#  - Document ID: doc_39998, Positions: [0]
#  - Document ID: doc_40010, Positions: [8, 19, 22]
#  - Document ID: doc_40018, Positions: [7]
#  - Document ID: doc_40040, Positions: [11]
#  - Document ID: doc_40064, Positions: [10]
#  - Document ID: doc_40085, Positions: [2]
#  - Document ID: doc_40110, Positions: [5, 14]
#  - Document ID: doc_40124, Positions: [1]
#  - Document ID: doc_40125, Positions: [1]
#  - Document ID: doc_40136, Positions: [2]
#  - Document ID: doc_40159, Positions: [5]
#  - Document ID: doc_40179, Positions: [1]
#  - Document ID: doc_40188, Positions: [0]
#  - Document ID: doc_40190, Positions: [7]
#  - Document ID: doc_40203, Positions: [3]
#  - Document ID: doc_40248, Positions: [3]
#  - Document ID: doc_40251, Positions: [12]
#  - Document ID: doc_40254, Positions: [6]
#  - Document ID: doc_40288, Positions: [4]
#  - Document ID: doc_40322, Positions: [1]
#  - Document ID: doc_40325, Positions: [1]
#  - Document ID: doc_40345, Positions: [6]
#  - Document ID: doc_40346, Positions: [10]
#  - Document ID: doc_40373, Positions: [4]
#  - Document ID: doc_40389, Positions: [1]
#  - Document ID: doc_40413, Positions: [3]
#  - Document ID: doc_40415, Positions: [1]
#  - Document ID: doc_40451, Positions: [7, 16]
#  - Document ID: doc_40465, Positions: [1]
#  - Document ID: doc_40472, Positions: [7]
#  - Document ID: doc_40501, Positions: [19]
#  - Document ID: doc_40525, Positions: [3]
#  - Document ID: doc_40534, Positions: [3]
#  - Document ID: doc_40576, Positions: [7]
#  - Document ID: doc_40582, Positions: [1, 9]
#  - Document ID: doc_40614, Positions: [6]
#  - Document ID: doc_40628, Positions: [3]
#  - Document ID: doc_40630, Positions: [1]
#  - Document ID: doc_40633, Positions: [26]
#  - Document ID: doc_40640, Positions: [6]
#  - Document ID: doc_40688, Positions: [20]
#  - Document ID: doc_40690, Positions: [2]
#  - Document ID: doc_40695, Positions: [10]
#  - Document ID: doc_40711, Positions: [6]
#  - Document ID: doc_40716, Positions: [4]
#  - Document ID: doc_40740, Positions: [1]
# ...
#  - Document ID: doc_38042, Positions: [14]
#  - Document ID: doc_38060, Positions: [7]
#  - Document ID: doc_38095, Positions: [18, 23]
#  - Document ID: doc_38167, Positions: [5]
#  - Document ID: doc_38211, Positions: [6]
#  - Document ID: doc_38289, Positions: [6]
#  - Document ID: doc_38313, Positions: [19]
#  - Document ID: doc_38345, Positions: [18]
#  - Document ID: doc_38354, Positions: [7]
#  - Document ID: doc_38404, Positions: [3]
#  - Document ID: doc_38435, Positions: [5, 21]
#  - Document ID: doc_38446, Positions: [5, 22]
#  - Document ID: doc_38448, Positions: [13]
#  - Document ID: doc_38466, Positions: [2, 12]
#  - Document ID: doc_38482, Positions: [5, 22]
#  - Document ID: doc_38510, Positions: [9, 10]
#  - Document ID: doc_38530, Positions: [5, 22]
#  - Document ID: doc_38549, Positions: [5]
#  - Document ID: doc_38576, Positions: [4]
#  - Document ID: doc_38593, Positions: [4, 25]
#  - Document ID: doc_38602, Positions: [5]
#  - Document ID: doc_38611, Positions: [1]
#  - Document ID: doc_38642, Positions: [2]
#  - Document ID: doc_38645, Positions: [25]
#  - Document ID: doc_38666, Positions: [12]
#  - Document ID: doc_38696, Positions: [10]
#  - Document ID: doc_38760, Positions: [7]
#  - Document ID: doc_38776, Positions: [22]
#  - Document ID: doc_38804, Positions: [9]
#  - Document ID: doc_38823, Positions: [0]
#  - Document ID: doc_38838, Positions: [18]
#  - Document ID: doc_38846, Positions: [10]
#  - Document ID: doc_38850, Positions: [7]
#  - Document ID: doc_38870, Positions: [0]
#  - Document ID: doc_38908, Positions: [1]
#  - Document ID: doc_38931, Positions: [12]
#  - Document ID: doc_38951, Positions: [12]
#  - Document ID: doc_39010, Positions: [1]
#  - Document ID: doc_39022, Positions: [4]
#  - Document ID: doc_39155, Positions: [10]
#  - Document ID: doc_39156, Positions: [16]
#  - Document ID: doc_39166, Positions: [5]
#  - Document ID: doc_39171, Positions: [13]
#  - Document ID: doc_39191, Positions: [1]
#  - Document ID: doc_39235, Positions: [4]
#  - Document ID: doc_39237, Positions: [9]
#  - Document ID: doc_39269, Positions: [9]
#  - Document ID: doc_39270, Positions: [6]
#  - Document ID: doc_39324, Positions: [20]
#  - Document ID: doc_39349, Positions: [5]
#  - Document ID: doc_39351, Positions: [16]
#  - Document ID: doc_39360, Positions: [5]
#  - Document ID: doc_39474, Positions: [5]
#  - Document ID: doc_39480, Positions: [8]
#  - Document ID: doc_39483, Positions: [8]
#  - Document ID: doc_39501, Positions: [11]
#  - Document ID: doc_39506, Positions: [24]
#  - Document ID: doc_39528, Positions: [7]
#  - Document ID: doc_39532, Positions: [3]
#  - Document ID: doc_39552, Positions: [4]
#  - Document ID: doc_39569, Positions: [1]
#  - Document ID: doc_39672, Positions: [2]
#  - Document ID: doc_39702, Positions: [19]
#  - Document ID: doc_39748, Positions: [11]
#  - Document ID: doc_39757, Positions: [3]
#  - Document ID: doc_39779, Positions: [2]
#  - Document ID: doc_39801, Positions: [4]
#  - Document ID: doc_39859, Positions: [19]
#  - Document ID: doc_39913, Positions: [8]
#  - Document ID: doc_39936, Positions: [6]
#  - Document ID: doc_39946, Positions: [4]
#  - Document ID: doc_39955, Positions: [2]
#  - Document ID: doc_39998, Positions: [1]
#  - Document ID: doc_39999, Positions: [5]
#  - Document ID: doc_40126, Positions: [5]
#  - Document ID: doc_40136, Positions: [3]
#  - Document ID: doc_40190, Positions: [17]
#  - Document ID: doc_40199, Positions: [27]
#  - Document ID: doc_40200, Positions: [2]
#  - Document ID: doc_40338, Positions: [21]
#  - Document ID: doc_40346, Positions: [5]
#  - Document ID: doc_40352, Positions: [21]
#  - Document ID: doc_40391, Positions: [3]
#  - Document ID: doc_40420, Positions: [16]
#  - Document ID: doc_40441, Positions: [11]
#  - Document ID: doc_40451, Positions: [8]
#  - Document ID: doc_40455, Positions: [2, 10]
#  - Document ID: doc_40503, Positions: [26]
#  - Document ID: doc_40512, Positions: [23]
#  - Document ID: doc_40513, Positions: [20]
#  - Document ID: doc_40525, Positions: [4]
#  - Document ID: doc_40534, Positions: [4]
#  - Document ID: doc_40609, Positions: [4]
#  - Document ID: doc_40654, Positions: [13]
#  - Document ID: doc_40674, Positions: [4]
#  - Document ID: doc_40682, Positions: [16, 22]
#  - Document ID: doc_40764, Positions: [7]
#  - Document ID: doc_40793, Positions: [14]
#  - Document ID: doc_40804, Positions: [3]
#  - Document ID: doc_40806, Positions: [8]
#  - Document ID: doc_40856, Positions: [21]
#  - Document ID: doc_40887, Positions: [10]
#  - Document ID: doc_40898, Positions: [8]
#  - Document ID: doc_40951, Positions: [2]
#  - Document ID: doc_40965, Positions: [9]
#  - Document ID: doc_40974, Positions: [7, 15]
#  - Document ID: doc_40980, Positions: [5]
#  - Document ID: doc_40994, Positions: [27]
#  - Document ID: doc_41000, Positions: [11, 17]
#  - Document ID: doc_41012, Positions: [2]
#  - Document ID: doc_41015, Positions: [11, 17]
#  - Document ID: doc_41033, Positions: [11, 17]
#  - Document ID: doc_41081, Positions: [11, 17]
#  - Document ID: doc_41126, Positions: [11, 17]
#  - Document ID: doc_41132, Positions: [2, 8]
#  - Document ID: doc_41141, Positions: [8]
#  - Document ID: doc_41151, Positions: [17]
#  - Document ID: doc_41175, Positions: [9]
#  - Document ID: doc_41196, Positions: [5, 7]
#  - Document ID: doc_41218, Positions: [3]
#  - Document ID: doc_41312, Positions: [1]
#  - Document ID: doc_41349, Positions: [8]
#  - Document ID: doc_41362, Positions: [2, 12]
#  - Document ID: doc_41403, Positions: [13]
#  - Document ID: doc_41439, Positions: [0]
#  - Document ID: doc_41450, Positions: [15]
#  - Document ID: doc_41451, Positions: [8]
#  - Document ID: doc_41455, Positions: [6]
#  - Document ID: doc_41458, Positions: [6]
#  - Document ID: doc_41468, Positions: [7]
#  - Document ID: doc_41491, Positions: [2]
#  - Document ID: doc_41493, Positions: [2]
#  - Document ID: doc_41541, Positions: [6]
#  - Document ID: doc_41555, Positions: [6]
#  - Document ID: doc_41562, Positions: [5]
#  - Document ID: doc_41577, Positions: [0]
#  - Document ID: doc_41584, Positions: [2]
#  - Document ID: doc_41602, Positions: [7]
#  - Document ID: doc_41654, Positions: [6]
#  - Document ID: doc_41659, Positions: [0]
#  - Document ID: doc_41669, Positions: [3, 13]
#  - Document ID: doc_41677, Positions: [4]
#  - Document ID: doc_41724, Positions: [23]
#  - Document ID: doc_41725, Positions: [21]
#  - Document ID: doc_41736, Positions: [11, 17]
#  - Document ID: doc_41741, Positions: [3]
#  - Document ID: doc_41751, Positions: [2, 15]
#  - Document ID: doc_41768, Positions: [11, 17]
#  - Document ID: doc_41792, Positions: [1, 7]
#  - Document ID: doc_41831, Positions: [6]
#  - Document ID: doc_41837, Positions: [8]
#  - Document ID: doc_41852, Positions: [31]
#  - Document ID: doc_41854, Positions: [1, 17, 32]
#  - Document ID: doc_41863, Positions: [1]
#  - Document ID: doc_41865, Positions: [2]
#  - Document ID: doc_42019, Positions: [6]
#  - Document ID: doc_42027, Positions: [17]
#  - Document ID: doc_42160, Positions: [15]
#  - Document ID: doc_42170, Positions: [25]
#  - Document ID: doc_42225, Positions: [11]
#  - Document ID: doc_42227, Positions: [22]
#  - Document ID: doc_42253, Positions: [11, 12]
#  - Document ID: doc_42265, Positions: [12]
#  - Document ID: doc_42364, Positions: [7, 13]
#  - Document ID: doc_42371, Positions: [18]
#  - Document ID: doc_42425, Positions: [22]
#  - Document ID: doc_42432, Positions: [0]
#  - Document ID: doc_42471, Positions: [2, 21]
#  - Document ID: doc_42612, Positions: [0, 21]
#  - Document ID: doc_42639, Positions: [9]
#  - Document ID: doc_42798, Positions: [9]
#  - Document ID: doc_42800, Positions: [21]
#  - Document ID: doc_42806, Positions: [5, 12]
#  - Document ID: doc_42809, Positions: [2]
#  - Document ID: doc_42816, Positions: [6]
#  - Document ID: doc_42864, Positions: [9]
#  - Document ID: doc_42899, Positions: [4]
#  - Document ID: doc_42916, Positions: [8]
#  - Document ID: doc_42952, Positions: [11, 15]
#  - Document ID: doc_42981, Positions: [1]
#  - Document ID: doc_42983, Positions: [0]
#  - Document ID: doc_43011, Positions: [7]
#  - Document ID: doc_43029, Positions: [10, 20]
#  - Document ID: doc_43133, Positions: [2]
#  - Document ID: doc_43161, Positions: [8]
#  - Document ID: doc_43185, Positions: [8]
#  - Document ID: doc_43195, Positions: [15]
#  - Document ID: doc_43196, Positions: [6]
#  - Document ID: doc_43224, Positions: [8]
#  - Document ID: doc_43237, Positions: [2]
#  - Document ID: doc_43252, Positions: [15]
#  - Document ID: doc_43288, Positions: [9]
#  - Document ID: doc_43289, Positions: [16, 18]
#  - Document ID: doc_43292, Positions: [13]
#  - Document ID: doc_43328, Positions: [1]
#  - Document ID: doc_43330, Positions: [1]
#  - Document ID: doc_43360, Positions: [1]
#  - Document ID: doc_43373, Positions: [3]
#  - Document ID: doc_43409, Positions: [4]
#  - Document ID: doc_43410, Positions: [5]
#  - Document ID: doc_43446, Positions: [10]
#  - Document ID: doc_43461, Positions: [4]
#  - Document ID: doc_43463, Positions: [15]
#  - Document ID: doc_43464, Positions: [6]
#  - Document ID: doc_43496, Positions: [7, 20]
#  - Document ID: doc_43518, Positions: [21]
#  - Document ID: doc_43542, Positions: [10]
#  - Document ID: doc_43598, Positions: [17]
#  - Document ID: doc_43624, Positions: [4]
#  - Document ID: doc_43660, Positions: [0]
#  - Document ID: doc_43684, Positions: [2]
#  - Document ID: doc_43727, Positions: [0]
#  - Document ID: doc_43731, Positions: [0]
#  - Document ID: doc_43734, Positions: [0]
#  - Document ID: doc_43737, Positions: [0]
#  - Document ID: doc_43745, Positions: [0]
#  - Document ID: doc_43748, Positions: [0]
#  - Document ID: doc_43750, Positions: [0]
#  - Document ID: doc_43754, Positions: [0]
#  - Document ID: doc_43776, Positions: [2]
#  - Document ID: doc_43814, Positions: [6]
#  - Document ID: doc_43847, Positions: [6]
#  - Document ID: doc_43925, Positions: [15]
#  - Document ID: doc_43954, Positions: [8, 12]
#  - Document ID: doc_43967, Positions: [5]
#  - Document ID: doc_44030, Positions: [2]
#  - Document ID: doc_44162, Positions: [16, 19]
#  - Document ID: doc_44247, Positions: [10]
#  - Document ID: doc_44268, Positions: [3]
#  - Document ID: doc_44512, Positions: [35]
#  - Document ID: doc_44519, Positions: [6]
#  - Document ID: doc_44522, Positions: [8]
#  - Document ID: doc_44548, Positions: [6]
#  - Document ID: doc_44553, Positions: [4]
#  - Document ID: doc_44612, Positions: [20]
#  - Document ID: doc_44640, Positions: [2]
#  - Document ID: doc_44715, Positions: [5]
#  - Document ID: doc_44797, Positions: [10]
#  - Document ID: doc_44807, Positions: [19]
#  - Document ID: doc_44884, Positions: [17]
#  - Document ID: doc_44910, Positions: [4]
#  - Document ID: doc_44928, Positions: [4]
#  - Document ID: doc_44931, Positions: [6, 12]
#  - Document ID: doc_44939, Positions: [5]
#  - Document ID: doc_44946, Positions: [2, 7]
#  - Document ID: doc_45002, Positions: [16]
#  - Document ID: doc_45007, Positions: [13, 17]
#  - Document ID: doc_45011, Positions: [22]
#  - Document ID: doc_45024, Positions: [20]
#  - Document ID: doc_45037, Positions: [7]
#  - Document ID: doc_45039, Positions: [2, 5, 9]
#  - Document ID: doc_45093, Positions: [13]
#  - Document ID: doc_45131, Positions: [4]
#  - Document ID: doc_45177, Positions: [11]
#  - Document ID: doc_45191, Positions: [7]
#  - Document ID: doc_45192, Positions: [8]
#  - Document ID: doc_45203, Positions: [12, 19]
#  - Document ID: doc_45214, Positions: [10]
#  - Document ID: doc_45246, Positions: [0]
#  - Document ID: doc_45288, Positions: [2, 12]
#  - Document ID: doc_45330, Positions: [22]
#  - Document ID: doc_45333, Positions: [2]
#  - Document ID: doc_45337, Positions: [2]
#  - Document ID: doc_45338, Positions: [2]
#  - Document ID: doc_45341, Positions: [2]
#  - Document ID: doc_45348, Positions: [12, 19]
#  - Document ID: doc_45367, Positions: [2]
#  - Document ID: doc_45369, Positions: [2]
#  - Document ID: doc_45414, Positions: [2]
#  - Document ID: doc_45434, Positions: [23]
#  - Document ID: doc_45436, Positions: [2]
#  - Document ID: doc_45501, Positions: [12]
#  - Document ID: doc_45502, Positions: [10]
#  - Document ID: doc_45537, Positions: [3]
#  - Document ID: doc_45582, Positions: [10]
#  - Document ID: doc_45592, Positions: [17]
#  - Document ID: doc_45600, Positions: [5, 15]
#  - Document ID: doc_45601, Positions: [21]
#  - Document ID: doc_45610, Positions: [14, 21]
#  - Document ID: doc_45626, Positions: [3]
#  - Document ID: doc_45667, Positions: [17]
#  - Document ID: doc_45676, Positions: [19]
#  - Document ID: doc_45781, Positions: [2, 12]
#  - Document ID: doc_45838, Positions: [15]
#  - Document ID: doc_45873, Positions: [4]
#  - Document ID: doc_45876, Positions: [6]
#  - Document ID: doc_45911, Positions: [11]
#  - Document ID: doc_45920, Positions: [23]
#  - Document ID: doc_45954, Positions: [3]
#  - Document ID: doc_46048, Positions: [16]
#  - Document ID: doc_46085, Positions: [6]
#  - Document ID: doc_46119, Positions: [28]
#  - Document ID: doc_46122, Positions: [3]
#  - Document ID: doc_46130, Positions: [10]
#  - Document ID: doc_46191, Positions: [6]
#  - Document ID: doc_46213, Positions: [12]
#  - Document ID: doc_46233, Positions: [11, 21]
#  - Document ID: doc_46234, Positions: [1]
#  - Document ID: doc_46246, Positions: [10]
#  - Document ID: doc_46427, Positions: [2]
#  - Document ID: doc_46443, Positions: [12]
#  - Document ID: doc_46495, Positions: [22]
#  - Document ID: doc_46520, Positions: [4]
#  - Document ID: doc_46535, Positions: [18]
#  - Document ID: doc_46573, Positions: [10]
#  - Document ID: doc_46606, Positions: [14]
#  - Document ID: doc_46607, Positions: [8]
#  - Document ID: doc_46614, Positions: [15]
#  - Document ID: doc_46634, Positions: [8]
#  - Document ID: doc_46671, Positions: [8, 14]
#  - Document ID: doc_46713, Positions: [4]
#  - Document ID: doc_46741, Positions: [5]
#  - Document ID: doc_46747, Positions: [15, 23]
#  - Document ID: doc_46764, Positions: [21]
#  - Document ID: doc_46789, Positions: [0]
#  - Document ID: doc_46797, Positions: [1]
#  - Document ID: doc_46822, Positions: [2]
#  - Document ID: doc_46852, Positions: [11]
#  - Document ID: doc_46867, Positions: [8]
#  - Document ID: doc_46931, Positions: [2]
#  - Document ID: doc_46935, Positions: [0]
#  - Document ID: doc_46969, Positions: [9]
#  - Document ID: doc_46977, Positions: [3, 11, 14]
#  - Document ID: doc_47053, Positions: [3]
#  - Document ID: doc_47061, Positions: [8]
#  - Document ID: doc_47067, Positions: [11]
#  - Document ID: doc_47069, Positions: [10]
#  - Document ID: doc_47074, Positions: [10]
#  - Document ID: doc_47077, Positions: [9]
#  - Document ID: doc_47086, Positions: [21]
#  - Document ID: doc_47087, Positions: [17]
#  - Document ID: doc_47088, Positions: [7]
#  - Document ID: doc_47090, Positions: [12]
#  - Document ID: doc_47092, Positions: [15]
#  - Document ID: doc_47096, Positions: [15]
#  - Document ID: doc_47100, Positions: [8]
#  - Document ID: doc_47103, Positions: [9]
#  - Document ID: doc_47110, Positions: [8]
#  - Document ID: doc_47143, Positions: [5]
#  - Document ID: doc_47156, Positions: [3]
#  - Document ID: doc_47419, Positions: [15]
#  - Document ID: doc_47444, Positions: [13]
#  - Document ID: doc_47464, Positions: [4]
#  - Document ID: doc_47520, Positions: [2]
#  - Document ID: doc_47522, Positions: [3]
#  - Document ID: doc_47551, Positions: [8]
#  - Document ID: doc_47553, Positions: [2]
#  - Document ID: doc_47610, Positions: [11]
#  - Document ID: doc_47619, Positions: [1]
#  - Document ID: doc_47688, Positions: [19]
#  - Document ID: doc_47702, Positions: [24]
#  - Document ID: doc_47746, Positions: [19]
#  - Document ID: doc_47755, Positions: [4, 19]
#  - Document ID: doc_47784, Positions: [2]
#  - Document ID: doc_47804, Positions: [1]
#  - Document ID: doc_47816, Positions: [17]
#  - Document ID: doc_47827, Positions: [10]
#  - Document ID: doc_47836, Positions: [11, 24]
#  - Document ID: doc_47931, Positions: [17]
#  - Document ID: doc_47941, Positions: [13]
#  - Document ID: doc_48057, Positions: [0]
#  - Document ID: doc_48128, Positions: [6]
#  - Document ID: doc_48163, Positions: [7]
#  - Document ID: doc_48197, Positions: [17]
#  - Document ID: doc_48205, Positions: [17]
#  - Document ID: doc_48323, Positions: [5]
#  - Document ID: doc_48325, Positions: [2]
#  - Document ID: doc_48329, Positions: [4]
#  - Document ID: doc_48350, Positions: [20]
#  - Document ID: doc_48396, Positions: [7]
#  - Document ID: doc_48403, Positions: [3]
#  - Document ID: doc_48425, Positions: [17]

# %%
from collections import defaultdict

# Function to compute the TF-IDF score for a term in a specific document
def compute_tf_idf(inverted_index, total_docs, term, doc_id):
    """
    Compute the TF-IDF score for a term in a specific document.

    Arguments:
    inverted_index -- the inverted index with terms as keys and posting lists as values
    total_docs -- total number of documents in the dataset
    term -- the term for which TF-IDF is being computed
    doc_id -- the ID of the document for which TF-IDF is being computed

    Returns:
    tf_idf -- the TF-IDF score for the term in the document
    """
    # Calculate Term Frequency (TF)
    term_occurrences = [posting for posting in inverted_index[term] if posting[0] == doc_id]
    if not term_occurrences:
        return 0
    tf = len(term_occurrences[0][1])  # Number of times the term appears in the document

    # Calculate Document Frequency (DF)
    df = len(inverted_index[term])  # Number of documents containing the term

    # Calculate TF-IDF using the formula TF * IDF
    idf = math.log(total_docs / (df + 1))  # Adding 1 to prevent division by zero
    tf_idf = tf * idf

    return tf_idf

# Function to build TF-IDF vectors for documents based on query terms
def build_document_vectors(inverted_index, query_terms, total_docs):
    """
    Build TF-IDF vectors for each document containing the query terms.

    Arguments:
    inverted_index -- the inverted index with terms as keys and posting lists as values
    query_terms -- list of terms in the query
    total_docs -- total number of documents in the dataset

    Returns:
    doc_vectors -- dictionary with document IDs as keys and TF-IDF vectors as values
    """
    doc_vectors = defaultdict(lambda: np.zeros(len(query_terms)))
    for i, term in enumerate(query_terms):
        if term in inverted_index:
            for doc_id, _ in inverted_index[term]:
                tf_idf_score = compute_tf_idf(inverted_index, total_docs, term, doc_id)
                doc_vectors[doc_id][i] = tf_idf_score
    return doc_vectors

# Function to build a TF-IDF vector for the query
def build_query_vector(inverted_index, query_terms, total_docs):
    """
    Build a TF-IDF vector for the query based on document statistics.

    Arguments:
    inverted_index -- the inverted index with terms as keys and posting lists as values
    query_terms -- list of terms in the query
    total_docs -- total number of documents in the dataset

    Returns:
    query_vector -- TF-IDF vector for the query
    """
    query_vector = np.zeros(len(query_terms))
    for i, term in enumerate(query_terms):
        # Calculate IDF for each term based on the actual document frequency in the inverted index
        if term in inverted_index:
            df = len(inverted_index[term])  # Document frequency for the term
            idf = math.log(total_docs / (df + 1))  # Adding 1 to prevent division by zero
            query_vector[i] = idf
    return query_vector

# Function to calculate cosine similarity between the query vector and each document vector
def cosine_similarity(query_vector, doc_vector):
    """
    Calculate cosine similarity between two vectors.

    Arguments:
    query_vector -- TF-IDF vector for the query
    doc_vector -- TF-IDF vector for a document

    Returns:
    similarity -- cosine similarity score between query and document vectors
    """
    # Calculate dot product between query and document vectors
    dot_product = np.dot(query_vector, doc_vector)

    # Calculate the magnitude of the query and document vectors
    query_magnitude = np.linalg.norm(query_vector)
    doc_magnitude = np.linalg.norm(doc_vector)

    # Compute cosine similarity (avoid division by zero)
    if query_magnitude == 0 or doc_magnitude == 0:
        return 0
    return dot_product / (query_magnitude * doc_magnitude)

# Function to rank documents based on cosine similarity with the query
def rank_documents_tf_idf_cosine(inverted_index, query_terms, total_docs):
    """
    Rank documents based on TF-IDF + Cosine Similarity.

    Arguments:
    inverted_index -- the inverted index with terms as keys and posting lists as values
    query_terms -- list of terms in the query
    total_docs -- total number of documents in the dataset

    Returns:
    ranked_docs -- list of documents sorted by their cosine similarity scores with the query
    """
    # Build TF-IDF vectors for documents
    doc_vectors = build_document_vectors(inverted_index, query_terms, total_docs)

    # Build the TF-IDF vector for the query
    query_vector = build_query_vector(inverted_index, query_terms, total_docs)

    # Calculate cosine similarity for each document and store the scores
    doc_scores = {}
    for doc_id, doc_vector in doc_vectors.items():
        similarity = cosine_similarity(query_vector, doc_vector)
        doc_scores[doc_id] = similarity

    # Sort documents by similarity score in descending order
    ranked_docs = sorted(doc_scores.items(), key=lambda x: x[1], reverse=True)
    return ranked_docs

# Query: "What is the Indian government view on the farmers' protest?"
query = "What is the Indian government view on the farmers' protest?"
query_processed = build_terms(query)
total_docs = len(tweet_to_doc_map)  # Total number of documents in the dataset
ranked_docs = rank_documents_tf_idf_cosine(inverted_index, query_processed, total_docs)

# Display the top 5 ranked documents
print("Top 20 Ranked Documents by TF-IDF + Cosine Similarity:")
for doc_id, score in ranked_docs[:20]:
    print(f"Document ID: {doc_id}, Cosine Similarity Score: {score}")
# Out:
# Top 20 Ranked Documents by TF-IDF + Cosine Similarity:
# Document ID: doc_1273, Cosine Similarity Score: 0.9321757179559246
# Document ID: doc_11265, Cosine Similarity Score: 0.9321757179559246
# Document ID: doc_16057, Cosine Similarity Score: 0.9321757179559246
# Document ID: doc_28464, Cosine Similarity Score: 0.9321757179559246
# Document ID: doc_20704, Cosine Similarity Score: 0.9262099832481728
# Document ID: doc_17156, Cosine Similarity Score: 0.8883695631933285
# Document ID: doc_21006, Cosine Similarity Score: 0.8883695631933285
# Document ID: doc_36129, Cosine Similarity Score: 0.8703493953287428
# Document ID: doc_18896, Cosine Similarity Score: 0.8653753366684499
# Document ID: doc_10548, Cosine Similarity Score: 0.8525353378102423
# Document ID: doc_13939, Cosine Similarity Score: 0.8525353378102423
# Document ID: doc_35711, Cosine Similarity Score: 0.8525353378102423
# Document ID: doc_3210, Cosine Similarity Score: 0.8474567278511329
# Document ID: doc_17899, Cosine Similarity Score: 0.8474567278511329
# Document ID: doc_28724, Cosine Similarity Score: 0.8474567278511329
# Document ID: doc_40576, Cosine Similarity Score: 0.8474567278511329
# Document ID: doc_16494, Cosine Similarity Score: 0.8408901649455093
# Document ID: doc_20585, Cosine Similarity Score: 0.8408901649455093
# Document ID: doc_20631, Cosine Similarity Score: 0.8408901649455093
# Document ID: doc_20658, Cosine Similarity Score: 0.8408901649455093

# %%
# Constants for BM25
k1 = 1.5  # Tuning parameter for term frequency scaling
b = 0.75  # Tuning parameter for document length scaling

# Function to compute the average document length in the collection
def compute_avg_doc_length(doc_lengths):
    return sum(doc_lengths.values()) / len(doc_lengths)

# Function to calculate the BM25 score for a term in a specific document
def bm25_term_score(N, df, tf, doc_len, avg_doc_len):
    """
    Compute the BM25 score for a term in a specific document.

    Arguments:
    N -- total number of documents
    df -- document frequency of the term
    tf -- term frequency of the term in the document
    doc_len -- length of the document
    avg_doc_len -- average document length in the collection

    Returns:
    score -- the BM25 score for the term in the document
    """
    # Calculate IDF component
    idf = math.log((N - df + 0.5) / (df + 0.5) + 1)

    # Calculate BM25 term frequency component
    term_freq_component = ((k1 + 1) * tf) / (k1 * ((1 - b) + b * (doc_len / avg_doc_len)) + tf)

    # Final BM25 score for the term in the document
    return idf * term_freq_component

# Function to rank documents based on BM25 score for a query
def rank_documents_bm25(inverted_index, query_terms, doc_lengths, total_docs):
    """
    Rank documents based on BM25 score for the given query terms.

    Arguments:
    inverted_index -- the inverted index with terms as keys and posting lists as values
    query_terms -- list of terms in the query
    doc_lengths -- dictionary with document IDs as keys and their lengths as values
    total_docs -- total number of documents in the dataset

    Returns:
    ranked_docs -- list of documents sorted by their cumulative BM25 scores (in descending order)
    """
    avg_doc_len = compute_avg_doc_length(doc_lengths)
    doc_scores = defaultdict(float)

    # Calculate BM25 score for each document with respect to each query term
    for term in query_terms:
        if term not in inverted_index:
            continue

        df = len(inverted_index[term])  # Document frequency of the term

        for doc_id, positions in inverted_index[term]:
            tf = len(positions)  # Term frequency of the term in the document
            doc_len = doc_lengths[doc_id]  # Length of the document

            # Calculate BM25 score for the term in the document
            term_score = bm25_term_score(total_docs, df, tf, doc_len, avg_doc_len)
            doc_scores[doc_id] += term_score  # Accumulate BM25 scores for each document

    # Sort documents by BM25 score in descending order
    ranked_docs = sorted(doc_scores.items(), key=lambda x: x[1], reverse=True)
    return ranked_docs

doc_lengths = {doc_id: len(tweet_info['Tweet'].split()) for doc_id, tweet_info in doc_tweet_map.items()}
total_docs = len(doc_tweet_map)

ranked_docs = rank_documents_bm25(inverted_index, query_processed, doc_lengths, total_docs)

# Display the top 5 ranked documents
print("Top 20 Ranked Documents by BM25:")
for doc_id, score in ranked_docs[:20]:
    print(f"Document ID: {doc_id}, BM25 Score: {score}")
# Out:
# Top 20 Ranked Documents by BM25:
# Document ID: doc_17156, BM25 Score: 13.636151512312594
# Document ID: doc_30422, BM25 Score: 13.168913200225282
# Document ID: doc_37712, BM25 Score: 10.871392391317688
# Document ID: doc_10923, BM25 Score: 10.79965400759432
# Document ID: doc_21006, BM25 Score: 10.359179922767837
# Document ID: doc_20704, BM25 Score: 10.358118906529452
# Document ID: doc_37241, BM25 Score: 10.333603630528476
# Document ID: doc_46909, BM25 Score: 10.328318411051908
# Document ID: doc_37560, BM25 Score: 10.177080587394158
# Document ID: doc_37209, BM25 Score: 10.169551073889046
# Document ID: doc_37219, BM25 Score: 10.169551073889046
# Document ID: doc_47837, BM25 Score: 10.088309541241681
# Document ID: doc_47839, BM25 Score: 10.088309541241681
# Document ID: doc_47841, BM25 Score: 10.088309541241681
# Document ID: doc_47843, BM25 Score: 10.088309541241681
# Document ID: doc_47845, BM25 Score: 10.088309541241681
# Document ID: doc_47848, BM25 Score: 10.088309541241681
# Document ID: doc_48027, BM25 Score: 10.088309541241681
# Document ID: doc_48059, BM25 Score: 10.088309541241681
# Document ID: doc_48070, BM25 Score: 10.088309541241681

# %%
# Define the P-Score calculation function
def calculate_p_score(likes, retweets, followers,
                      alpha=0.5, beta=1.0, delta=0.8):
    """
    Calculate the P-Score for a tweet based on social media engagement metrics.

    Parameters:
    - likes (int): Number of likes the tweet received.
    - retweets (int): Number of retweets the tweet received.
    - followers (int): Number of followers of the tweet's author.
    - alpha (float): Weight for likes. Default is 0.5.
    - beta (float): Weight for retweets. Default is 1.0.
    - delta (float): Weight for engagement ratio. Default is 0.8.

    Returns:
    - float: The computed P-Score for the tweet.
    """
    total_interactions = likes + retweets
    engagement_ratio = total_interactions / followers if followers > 0 else 0
    p_score = (alpha * likes) + (beta * retweets) + (delta * engagement_ratio)
    return p_score

# Calculate and rank documents by P-Score
def rank_documents_by_p_score(doc_tweet_map):
    """
    Calculate P-Scores for all tweets and rank the documents based on these scores.

    Parameters:
    - doc_tweet_map (dict): Dictionary where keys are document IDs and values are dictionaries containing tweet info

    Returns:
    - ranked_docs (list): List of tuples (document ID, P-Score) sorted by P-Score in descending order
    """
    p_scores = {}

    for doc_id, tweet_info in doc_tweet_map.items():
        # Extract engagement metrics from tweet_info
        likes = tweet_info.get('Likes', 0)
        retweets = tweet_info.get('Retweets', 0)
        followers = tweet_info.get('Followers', 1)  # Defaulting to 1 to avoid division by zero if followers are missing

        # Calculate the P-Score for this tweet
        p_score = calculate_p_score(likes, retweets, followers)

        # Store the P-Score for this document
        p_scores[doc_id] = p_score

    # Sort documents by P-Score in descending order
    ranked_docs = sorted(p_scores.items(), key=lambda x: x[1], reverse=True)

    return ranked_docs

# Rank documents by P-Score
ranked_docs = rank_documents_by_p_score(doc_tweet_map)

# Display the top-ranked documents based on P-Score
print("Top-ranked documents by P-Score:")
for doc_id, score in ranked_docs[:20]:  # Display top 5 results
    print(f"Document ID: {doc_id}, P-Score: {score}")
# Out:
# Top-ranked documents by P-Score:
# Document ID: doc_3203, P-Score: 47349.600000000006
# Document ID: doc_46206, P-Score: 28520.100000000002
# Document ID: doc_45142, P-Score: 22561.300000000003
# Document ID: doc_38012, P-Score: 20259.5
# Document ID: doc_38410, P-Score: 20077.6
# Document ID: doc_38262, P-Score: 19929.300000000003
# Document ID: doc_35993, P-Score: 17205.0
# Document ID: doc_27071, P-Score: 15231.2
# Document ID: doc_9846, P-Score: 13910.6
# Document ID: doc_38379, P-Score: 12391.0
# Document ID: doc_41472, P-Score: 11900.8
# Document ID: doc_28154, P-Score: 11785.5
# Document ID: doc_18306, P-Score: 11322.7
# Document ID: doc_23286, P-Score: 10439.8
# Document ID: doc_27974, P-Score: 9859.5
# Document ID: doc_31312, P-Score: 9262.6
# Document ID: doc_46278, P-Score: 9015.8
# Document ID: doc_13132, P-Score: 8902.400000000001
# Document ID: doc_28056, P-Score: 8575.8
# Document ID: doc_16447, P-Score: 8402.5

# %%
import gensim.downloader as api
from gensim.models import KeyedVectors, Word2Vec
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# Load the word2vec model
model = api.load("word2vec-google-news-300")

# Function to compute the average Word2Vec vector for a document
def average_word2vec_vector(text, model, vector_size=300):
    """Compute the average Word2Vec vector for a given text."""
    words = text.split()
    word_vectors = [model[word] for word in words if word in model]
    if not word_vectors:
        return np.zeros(vector_size)
    return np.mean(word_vectors, axis=0)

# Create document vectors for all tweets in the dataset
doc_vectors = {}
for doc_id, tweet_info in doc_tweet_map.items():
    tweet_text = tweet_info['Tweet']
    doc_vectors[doc_id] = average_word2vec_vector(tweet_text, model)

# Define multi-word queries
multi_word_queries = [
    "farmers protest",
    "indian government",
    "support farmers",
    "police action",
    "human rights"
]

# Preprocess and compute the query vectors
query_vectors = {}
for i, query in enumerate(multi_word_queries, 1):
    processed_query = ' '.join(build_terms(query))
    query_vectors[i] = average_word2vec_vector(processed_query, model)

# Rank documents for each query based on cosine similarity
def rank_documents_word2vec_cosine(query_vectors, doc_vectors):
    """
    Rank documents for each query using cosine similarity with Word2Vec vectors.
    Returns top 20 documents for each query.
    """
    ranked_results = {}

    for query_id, query_vector in query_vectors.items():
        doc_scores = {}

        # Calculate cosine similarity between the query vector and each document vector
        for doc_id, doc_vector in doc_vectors.items():
            if np.linalg.norm(doc_vector) != 0 and np.linalg.norm(query_vector) != 0:  # Avoid zero vectors
                similarity = cosine_similarity([query_vector], [doc_vector])[0][0]
                doc_scores[doc_id] = similarity

        # Sort documents by similarity score in descending order and take top 20
        ranked_results[query_id] = sorted(doc_scores.items(), key=lambda x: x[1], reverse=True)[:20]

    return ranked_results

# Run the ranking for each query
ranked_docs = rank_documents_word2vec_cosine(query_vectors, doc_vectors)

# Display the top 20 ranked documents for each query
for query_id, results in ranked_docs.items():
    print(f"\nTop 20 Ranked Documents for Query '{multi_word_queries[query_id - 1]}':")
    for doc_id, score in results:
        print(f"Document ID: {doc_id}, Cosine Similarity Score: {score}")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
#
# Top 20 Ranked Documents for Query 'farmers protest':
# Document ID: doc_3521, Cosine Similarity Score: 1.0
# Document ID: doc_4681, Cosine Similarity Score: 1.0
# Document ID: doc_5727, Cosine Similarity Score: 1.0
# Document ID: doc_5973, Cosine Similarity Score: 1.0
# Document ID: doc_7295, Cosine Similarity Score: 1.0
# Document ID: doc_7433, Cosine Similarity Score: 1.0
# Document ID: doc_7438, Cosine Similarity Score: 1.0
# Document ID: doc_11824, Cosine Similarity Score: 1.0
# Document ID: doc_12388, Cosine Similarity Score: 1.0
# Document ID: doc_14759, Cosine Similarity Score: 1.0
# Document ID: doc_16557, Cosine Similarity Score: 1.0
# Document ID: doc_20024, Cosine Similarity Score: 1.0
# Document ID: doc_20877, Cosine Similarity Score: 1.0
# Document ID: doc_21162, Cosine Similarity Score: 1.0
# Document ID: doc_21259, Cosine Similarity Score: 1.0
# Document ID: doc_21323, Cosine Similarity Score: 1.0
# Document ID: doc_21436, Cosine Similarity Score: 1.0
# Document ID: doc_21450, Cosine Similarity Score: 1.0
# Document ID: doc_22147, Cosine Similarity Score: 1.0
# Document ID: doc_24115, Cosine Similarity Score: 1.0
#
# Top 20 Ranked Documents for Query 'indian government':
# Document ID: doc_3116, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_8470, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_11484, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_12228, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_14237, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_17769, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_26363, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_29545, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_31710, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_35081, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_38240, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_40124, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_40125, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_41848, Cosine Similarity Score: 0.891823947429657
# Document ID: doc_31188, Cosine Similarity Score: 0.8879555463790894
# Document ID: doc_36091, Cosine Similarity Score: 0.8755002021789551
# Document ID: doc_30419, Cosine Similarity Score: 0.869872510433197
# Document ID: doc_39942, Cosine Similarity Score: 0.8606048822402954
# Document ID: doc_27778, Cosine Similarity Score: 0.8587357997894287
# Document ID: doc_15526, Cosine Similarity Score: 0.8576177358627319
#
# Top 20 Ranked Documents for Query 'support farmers':
# Document ID: doc_357, Cosine Similarity Score: 1.0
# Document ID: doc_506, Cosine Similarity Score: 1.0
# Document ID: doc_590, Cosine Similarity Score: 1.0
# Document ID: doc_651, Cosine Similarity Score: 1.0
# Document ID: doc_659, Cosine Similarity Score: 1.0
# Document ID: doc_1244, Cosine Similarity Score: 1.0
# Document ID: doc_1263, Cosine Similarity Score: 1.0
# Document ID: doc_1268, Cosine Similarity Score: 1.0
# Document ID: doc_1290, Cosine Similarity Score: 1.0
# Document ID: doc_1468, Cosine Similarity Score: 1.0
# Document ID: doc_1699, Cosine Similarity Score: 1.0
# Document ID: doc_1714, Cosine Similarity Score: 1.0
# Document ID: doc_1830, Cosine Similarity Score: 1.0
# Document ID: doc_2025, Cosine Similarity Score: 1.0
# Document ID: doc_2402, Cosine Similarity Score: 1.0
# Document ID: doc_2581, Cosine Similarity Score: 1.0
# Document ID: doc_2815, Cosine Similarity Score: 1.0
# Document ID: doc_3258, Cosine Similarity Score: 1.0
# Document ID: doc_3265, Cosine Similarity Score: 1.0
# Document ID: doc_3817, Cosine Similarity Score: 1.0
#
# Top 20 Ranked Documents for Query 'police action':
# Document ID: doc_32026, Cosine Similarity Score: 0.867011308670044
# Document ID: doc_13980, Cosine Similarity Score: 0.7737770080566406
# Document ID: doc_24374, Cosine Similarity Score: 0.7737770080566406
# Document ID: doc_32593, Cosine Similarity Score: 0.7533147931098938
# Document ID: doc_32988, Cosine Similarity Score: 0.678797721862793
# Document ID: doc_10270, Cosine Similarity Score: 0.6779404282569885
# Document ID: doc_5961, Cosine Similarity Score: 0.6499655246734619
# Document ID: doc_42061, Cosine Similarity Score: 0.6346209645271301
# Document ID: doc_29611, Cosine Similarity Score: 0.632702112197876
# Document ID: doc_18802, Cosine Similarity Score: 0.6309041380882263
# Document ID: doc_32162, Cosine Similarity Score: 0.6133252382278442
# Document ID: doc_14499, Cosine Similarity Score: 0.6037903428077698
# Document ID: doc_14667, Cosine Similarity Score: 0.6037903428077698
# Document ID: doc_18257, Cosine Similarity Score: 0.5989580154418945
# Document ID: doc_299, Cosine Similarity Score: 0.5988134145736694
# Document ID: doc_12735, Cosine Similarity Score: 0.5824165940284729
# Document ID: doc_23142, Cosine Similarity Score: 0.5803090929985046
# Document ID: doc_3174, Cosine Similarity Score: 0.578309953212738
# Document ID: doc_3360, Cosine Similarity Score: 0.5769809484481812
# Document ID: doc_33546, Cosine Similarity Score: 0.5737453103065491
#
# Top 20 Ranked Documents for Query 'human rights':
# Document ID: doc_34885, Cosine Similarity Score: 1.0000001192092896
# Document ID: doc_29293, Cosine Similarity Score: 0.9373530745506287
# Document ID: doc_29069, Cosine Similarity Score: 0.899179995059967
# Document ID: doc_29072, Cosine Similarity Score: 0.899179995059967
# Document ID: doc_2732, Cosine Similarity Score: 0.8783642053604126
# Document ID: doc_16748, Cosine Similarity Score: 0.8783642053604126
# Document ID: doc_30836, Cosine Similarity Score: 0.8645249009132385
# Document ID: doc_24319, Cosine Similarity Score: 0.8464946150779724
# Document ID: doc_14493, Cosine Similarity Score: 0.8394662737846375
# Document ID: doc_3568, Cosine Similarity Score: 0.821799099445343
# Document ID: doc_6599, Cosine Similarity Score: 0.821799099445343
# Document ID: doc_29303, Cosine Similarity Score: 0.821799099445343
# Document ID: doc_39476, Cosine Similarity Score: 0.8036061525344849
# Document ID: doc_16224, Cosine Similarity Score: 0.8014854788780212
# Document ID: doc_17777, Cosine Similarity Score: 0.8014854788780212
# Document ID: doc_18107, Cosine Similarity Score: 0.8014854788780212
# Document ID: doc_18695, Cosine Similarity Score: 0.8014854788780212
# Document ID: doc_24957, Cosine Similarity Score: 0.8014854788780212
# Document ID: doc_1653, Cosine Similarity Score: 0.8004111051559448
# Document ID: doc_15569, Cosine Similarity Score: 0.8004111051559448
